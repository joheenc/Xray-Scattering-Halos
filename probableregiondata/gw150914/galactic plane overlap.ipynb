# %%
import pandas as pd
import matplotlib.pyplot as plt
probmap = pd.read_csv('probmap.csv')
gplane = probmap[(probmap.b > -5) & (probmap.b < 5)]
plt.scatter(gplane['ra'], gplane['dec'], c=gplane['prob'])
