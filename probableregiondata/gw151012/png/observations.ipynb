# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
hdul = fits.open('../events/sw00092110005xpcw3po_cl.evt.gz')
x = hdul[1].data['X']
y = hdul[1].data['Y']
pi = hdul[1].data['PI']
filteredindices = np.where(pi>80)
plt.hist(pi[filteredindices], bins=40)
plt.show()
plt.clf()
fig, ax = plt.subplots(figsize=(16, 12))
img = plt.scatter(x[filteredindices], y[filteredindices], c=pi[filteredindices])
plt.colorbar(img)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 12))
ax.set_facecolor('black')
# ax.add_artist(plt.Circle((530, 400), 195, fill=False, color='red'))
plt.scatter(x[filteredindices], y[filteredindices], color='white', s=4)
