# %%
import pandas as pd
file = open('swiftgplane.txt', 'r')
df = pd.DataFrame()
targetid = []
obsid = []
ra = []
dec = []
date = []
exposure = []
name = []
b = []
i = 0
for line in file.readlines():
    arr = line.split('|')
    targetid.append(arr[1].strip())
    obsid.append(arr[2].strip())
    ra.append(float(arr[3].strip().split()[0])*15. + float(arr[3].strip().split()[1])*15./60. + float(arr[3].strip().split()[2])*15./360.)
    dec.append(float(arr[4].strip().split()[0]) + float(arr[4].strip().split()[1])/60. + float(arr[4].strip().split()[2])/360.)
    date.append(arr[5].strip())
    exposure.append(float(arr[6].strip()))
    name.append(arr[9].strip())
    b.append(float(arr[10].strip()))
df['targetid'] = targetid
df['obsid'] = obsid
df['ra'] = ra
df['dec'] = dec
df['date'] = date
df['exposure'] = exposure
df['name'] = name
df['b'] = b
df.head()
# Out:
#   targetid        obsid          ra        dec                   date  \
# 0   701590  00701590000  295.724583  21.953611  2016-06-26 13:56:39.8
# 1   992099  00992099001   22.755417  63.108611  2020-08-19 16:47:05.2
# 2   701590  00701590000  295.724583  21.953611  2016-06-26 18:44:28.7
# 3   701590  00701590000  295.724583  21.953611  2016-06-26 15:33:07.7
# 4   778435  00778435001   84.960000  34.495556  2017-10-13 04:38:56.4
#
#      exposure                    name        b
# 0  2587.17894        Automatic Target  0.83069
# 1  2552.21924  Burst (21.424, 63.061)  0.41062
# 2  2542.23069        Automatic Target  0.83069
# 3  2542.22831        Automatic Target  0.83069
# 4  2519.75025  Burst (84.096, 34.455)  1.25591

# %%
import matplotlib.pyplot as plt
import os
plt.figure(figsize=(16, 8))
plt.xlim(0, 360)
plt.ylim(-90, 90)
plt.yticks(range(-90, 91, 30))
plt.xticks(range(0, 361, 30))

cmaps = ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds', 'YlOrBr', 'OrRd', 'PuRd', 'BuPu', 'GnBu', 'PuBuGn', 'YlGnBu']
i = 0
for dir in os.listdir('.'):
    if 'gw' in dir:
        probmap = pd.read_csv(dir + '/probmap.csv')
        probmaplikely = probmap[(probmap.b < 2) & (probmap.b > -2) & (probmap.prob > 0.001)]
        probmaplikely = probmap[probmap.prob > 10**-4]
        plt.scatter(probmaplikely.ra, probmaplikely.dec, c=probmaplikely.prob, cmap=cmaps[i])
        i += 1


r1 = df[(df.ra>62) & (df.ra<72) & (df.dec>39) & (df.dec<53)]     #done
r2 = df[(df.ra>106) & (df.ra<108) & (df.dec>-10) & (df.dec<-5)]  #done
r3 = df[(df.ra>228) & (df.ra<235) & (df.dec>-70) & (df.dec<-52)] #done
r4 = df[(df.ra>253) & (df.ra<261) & (df.dec>-46) & (df.dec<-35)] #done
r5 = df[(df.ra>275) & (df.ra<283) & (df.dec>-20) & (df.dec<-10)]

plt.scatter(df.ra, df.dec, color='gray', s=2, alpha=0.1)
plt.scatter(r1.ra, r1.dec)
plt.scatter(r2.ra, r2.dec)
plt.scatter(r3.ra, r3.dec)
plt.scatter(r4.ra, r4.dec)
plt.scatter(r5.ra, r5.dec)

# %%
swiftobs = r1.append(r2, ignore_index=True).append(r3, ignore_index=True).append(r4, ignore_index=True).append(r5, ignore_index=True)
swiftobs
# Out:
#      targetid        obsid          ra        dec                   date  \
# 0       10734  00010734010   71.802917  47.422778    2018-08-31 07:42:48
# 1       10734  00010734016   71.873333  47.526944  2018-10-26 13:37:01.3
# 2       10734  00010734001   71.541667  47.460000  2018-07-20 03:28:42.1
# 3       10734  00010734045   71.907500  47.408889  2020-08-23 21:31:16.1
# 4       10734  00010734036   71.979583  47.472222  2019-09-16 16:39:50.2
# ...       ...          ...         ...        ...                    ...
# 1725   960986  00960986001  276.463333 -15.778333  2020-03-13 05:12:09.4
# 1726  3110764  03110764001  278.326250 -12.562778  2020-03-26 16:46:50.5
# 1727  3110764  03110764003  278.490417 -12.681111  2020-05-30 20:10:28.8
# 1728  3110764  03110764001  278.326250 -12.562778  2020-03-26 10:36:45.2
# 1729  3110729  03110729001  277.056250 -13.022500  2020-02-15 01:47:42.2
#
#         exposure               name        b
# 0     1618.23663            V392Per  0.89092
# 1     1605.75352            V392Per  0.93088
# 2     1565.79351            V392Per  0.94890
# 3     1530.83234            V392Per  0.90520
# 4     1495.86867            V392Per  0.92289
# ...          ...                ...      ...
# 1725    52.44285  SwiftJ1818.0-1607 -0.09680
# 1726    49.94555   SGPSJ1824.9-1318 -0.28283
# 1727    24.97280   SGPSJ1824.9-1318 -0.30542
# 1728     7.49187   SGPSJ1824.9-1318 -0.28283
# 1729     7.49182   SGPSJ1819.9-1459  0.00516
#
# [1730 rows x 8 columns]

# %%
swiftobs.to_csv('swift_gplane_probregion.csv')

# %%
from shutil import copyfile
for dir in os.listdir('galacticplane/swift'):
    if '0' in dir:
        print(os.listdir('galacticplane/swift/' + dir + '/xrt/event/'))
# Out:
# ['sw00010073001xpcw3po_cl.evt.gz', 'sw00010073001xpcw3po_uf.evt.gz', 'sw00010073001xwtw2sl_cl.evt.gz', 'sw00010073001xwtw2sl_uf.evt.gz', 'sw00010073001xwtw2sl_ufre.evt.gz', 'sw00010073001xwtw2st_cl.evt.gz', 'sw00010073001xwtw2st_uf.evt.gz', 'sw00010073001xwtw2st_ufre.evt.gz']
# ['sw00010073002xpcw3po_cl.evt.gz', 'sw00010073002xpcw3po_uf.evt.gz', 'sw00010073002xwtw2sl_cl.evt.gz', 'sw00010073002xwtw2sl_uf.evt.gz', 'sw00010073002xwtw2sl_ufre.evt.gz', 'sw00010073002xwtw2st_cl.evt.gz', 'sw00010073002xwtw2st_uf.evt.gz', 'sw00010073002xwtw2st_ufre.evt.gz']
# ['sw00010186001xpcw3po_cl.evt.gz', 'sw00010186001xpcw3po_uf.evt.gz', 'sw00010186001xwtw2sl_cl.evt.gz', 'sw00010186001xwtw2sl_uf.evt.gz', 'sw00010186001xwtw2sl_ufre.evt.gz', 'sw00010186001xwtw2st_cl.evt.gz', 'sw00010186001xwtw2st_uf.evt.gz', 'sw00010186001xwtw2st_ufre.evt.gz']
# ['sw00010186002xpcw3po_cl.evt.gz', 'sw00010186002xpcw3po_uf.evt.gz', 'sw00010186002xwtw2st_cl.evt.gz', 'sw00010186002xwtw2st_uf.evt.gz', 'sw00010186002xwtw2st_ufre.evt.gz']
# ['sw00010186003xpcw3po_cl.evt.gz', 'sw00010186003xpcw3po_uf.evt.gz']
# ['sw00010186004xpcw3po_cl.evt.gz', 'sw00010186004xpcw3po_uf.evt.gz', 'sw00010186004xwtw2st_cl.evt.gz', 'sw00010186004xwtw2st_uf.evt.gz', 'sw00010186004xwtw2st_ufre.evt.gz']
# ['sw00010186005xpcw3po_cl.evt.gz', 'sw00010186005xpcw3po_uf.evt.gz', 'sw00010186005xwtw2sl_cl.evt.gz', 'sw00010186005xwtw2sl_uf.evt.gz', 'sw00010186005xwtw2sl_ufre.evt.gz', 'sw00010186005xwtw2st_cl.evt.gz', 'sw00010186005xwtw2st_uf.evt.gz', 'sw00010186005xwtw2st_ufre.evt.gz']
# ['sw00010186006xpcw3po_cl.evt.gz', 'sw00010186006xpcw3po_uf.evt.gz', 'sw00010186006xwtw2st_cl.evt.gz', 'sw00010186006xwtw2st_uf.evt.gz', 'sw00010186006xwtw2st_ufre.evt.gz']
# ['sw00010186007xpcw3po_cl.evt.gz', 'sw00010186007xpcw3po_uf.evt.gz', 'sw00010186007xwtw2sl_cl.evt.gz', 'sw00010186007xwtw2sl_uf.evt.gz', 'sw00010186007xwtw2sl_ufre.evt.gz', 'sw00010186007xwtw2st_cl.evt.gz', 'sw00010186007xwtw2st_uf.evt.gz', 'sw00010186007xwtw2st_ufre.evt.gz']
# ['sw00010186008xpcw3po_cl.evt.gz', 'sw00010186008xpcw3po_uf.evt.gz', 'sw00010186008xwtw2st_cl.evt.gz', 'sw00010186008xwtw2st_uf.evt.gz', 'sw00010186008xwtw2st_ufre.evt.gz']
# ['sw00010186009xpcw3po_cl.evt.gz', 'sw00010186009xpcw3po_uf.evt.gz', 'sw00010186009xwtw2sl_cl.evt.gz', 'sw00010186009xwtw2sl_uf.evt.gz', 'sw00010186009xwtw2sl_ufre.evt.gz', 'sw00010186009xwtw2st_cl.evt.gz', 'sw00010186009xwtw2st_uf.evt.gz', 'sw00010186009xwtw2st_ufre.evt.gz']
# ['sw00010186010xpcw3po_cl.evt.gz', 'sw00010186010xpcw3po_uf.evt.gz', 'sw00010186010xwtw2st_cl.evt.gz', 'sw00010186010xwtw2st_uf.evt.gz', 'sw00010186010xwtw2st_ufre.evt.gz']
# ['sw00010186011xpcw3po_cl.evt.gz', 'sw00010186011xpcw3po_uf.evt.gz', 'sw00010186011xwtw2sl_cl.evt.gz', 'sw00010186011xwtw2sl_uf.evt.gz', 'sw00010186011xwtw2sl_ufre.evt.gz', 'sw00010186011xwtw2st_cl.evt.gz', 'sw00010186011xwtw2st_uf.evt.gz', 'sw00010186011xwtw2st_ufre.evt.gz']
# ['sw00010186012xpcw3po_cl.evt.gz', 'sw00010186012xpcw3po_uf.evt.gz', 'sw00010186012xwtw2sl_cl.evt.gz', 'sw00010186012xwtw2sl_uf.evt.gz', 'sw00010186012xwtw2sl_ufre.evt.gz', 'sw00010186012xwtw2st_cl.evt.gz', 'sw00010186012xwtw2st_uf.evt.gz', 'sw00010186012xwtw2st_ufre.evt.gz']
# ['sw00010186013xpcw3po_cl.evt.gz', 'sw00010186013xpcw3po_uf.evt.gz', 'sw00010186013xwtw2st_cl.evt.gz', 'sw00010186013xwtw2st_uf.evt.gz', 'sw00010186013xwtw2st_ufre.evt.gz']
# ['sw00010186014xpcw3po_cl.evt.gz', 'sw00010186014xpcw3po_uf.evt.gz', 'sw00010186014xwtw2sl_cl.evt.gz', 'sw00010186014xwtw2sl_uf.evt.gz', 'sw00010186014xwtw2sl_ufre.evt.gz', 'sw00010186014xwtw2st_cl.evt.gz', 'sw00010186014xwtw2st_uf.evt.gz', 'sw00010186014xwtw2st_ufre.evt.gz']
# ['sw00010186015xpcw3po_cl.evt.gz', 'sw00010186015xpcw3po_uf.evt.gz', 'sw00010186015xwtw2st_cl.evt.gz', 'sw00010186015xwtw2st_uf.evt.gz', 'sw00010186015xwtw2st_ufre.evt.gz']
# ['sw00010188001xpcw3po_cl.evt.gz', 'sw00010188001xpcw3po_uf.evt.gz', 'sw00010188001xwtw2sl_cl.evt.gz', 'sw00010188001xwtw2sl_uf.evt.gz', 'sw00010188001xwtw2sl_ufre.evt.gz', 'sw00010188001xwtw2st_cl.evt.gz', 'sw00010188001xwtw2st_uf.evt.gz', 'sw00010188001xwtw2st_ufre.evt.gz']
# ['sw00010188002xpcw3po_cl.evt.gz', 'sw00010188002xpcw3po_uf.evt.gz', 'sw00010188002xwtw2sl_cl.evt.gz', 'sw00010188002xwtw2sl_uf.evt.gz', 'sw00010188002xwtw2sl_ufre.evt.gz', 'sw00010188002xwtw2st_cl.evt.gz', 'sw00010188002xwtw2st_uf.evt.gz', 'sw00010188002xwtw2st_ufre.evt.gz']
# ['sw00010211001xpcw3po_cl.evt.gz', 'sw00010211001xpcw3po_uf.evt.gz', 'sw00010211001xwtw2sl_cl.evt.gz', 'sw00010211001xwtw2sl_uf.evt.gz', 'sw00010211001xwtw2sl_ufre.evt.gz', 'sw00010211001xwtw2st_cl.evt.gz', 'sw00010211001xwtw2st_uf.evt.gz', 'sw00010211001xwtw2st_ufre.evt.gz']
# ['sw00010211002xpcw3po_cl.evt.gz', 'sw00010211002xpcw3po_uf.evt.gz', 'sw00010211002xwtw2sl_cl.evt.gz', 'sw00010211002xwtw2sl_uf.evt.gz', 'sw00010211002xwtw2sl_ufre.evt.gz', 'sw00010211002xwtw2st_cl.evt.gz', 'sw00010211002xwtw2st_uf.evt.gz', 'sw00010211002xwtw2st_ufre.evt.gz']
# ['sw00010211003xpcw3po_cl.evt.gz', 'sw00010211003xpcw3po_uf.evt.gz', 'sw00010211003xwtw2sl_cl.evt.gz', 'sw00010211003xwtw2sl_uf.evt.gz', 'sw00010211003xwtw2sl_ufre.evt.gz', 'sw00010211003xwtw2st_cl.evt.gz', 'sw00010211003xwtw2st_uf.evt.gz', 'sw00010211003xwtw2st_ufre.evt.gz']
# ['sw00010211004xpcw3po_cl.evt.gz', 'sw00010211004xpcw3po_uf.evt.gz', 'sw00010211004xwtw2st_cl.evt.gz', 'sw00010211004xwtw2st_uf.evt.gz', 'sw00010211004xwtw2st_ufre.evt.gz']
# ['sw00010211005xpcw3po_cl.evt.gz', 'sw00010211005xpcw3po_uf.evt.gz', 'sw00010211005xwtw2sl_cl.evt.gz', 'sw00010211005xwtw2sl_uf.evt.gz', 'sw00010211005xwtw2sl_ufre.evt.gz', 'sw00010211005xwtw2st_cl.evt.gz', 'sw00010211005xwtw2st_uf.evt.gz', 'sw00010211005xwtw2st_ufre.evt.gz']
# ['sw00010211006xpcw3po_cl.evt.gz', 'sw00010211006xpcw3po_uf.evt.gz', 'sw00010211006xwtw2st_cl.evt.gz', 'sw00010211006xwtw2st_uf.evt.gz', 'sw00010211006xwtw2st_ufre.evt.gz']
# ['sw00010211007xpcw3po_cl.evt.gz', 'sw00010211007xpcw3po_uf.evt.gz', 'sw00010211007xwtw2sl_cl.evt.gz', 'sw00010211007xwtw2sl_uf.evt.gz', 'sw00010211007xwtw2sl_ufre.evt.gz', 'sw00010211007xwtw2st_cl.evt.gz', 'sw00010211007xwtw2st_uf.evt.gz', 'sw00010211007xwtw2st_ufre.evt.gz']
# ['sw00010211008xpcw3po_cl.evt.gz', 'sw00010211008xpcw3po_uf.evt.gz', 'sw00010211008xwtw2st_cl.evt.gz', 'sw00010211008xwtw2st_uf.evt.gz', 'sw00010211008xwtw2st_ufre.evt.gz']
# ['sw00010264043xpcw3po_cl.evt.gz', 'sw00010264043xpcw3po_uf.evt.gz', 'sw00010264043xpcw3sl_cl.evt.gz', 'sw00010264043xpcw3sl_uf.evt.gz', 'sw00010264043xpcw3st_cl.evt.gz', 'sw00010264043xpcw3st_uf.evt.gz', 'sw00010264043xwtw2po_cl.evt.gz', 'sw00010264043xwtw2po_uf.evt.gz', 'sw00010264043xwtw2po_ufre.evt.gz']
# ['sw00010264046xpcw3po_cl.evt.gz', 'sw00010264046xpcw3po_uf.evt.gz', 'sw00010264046xwtw2po_cl.evt.gz', 'sw00010264046xwtw2po_uf.evt.gz', 'sw00010264046xwtw2po_ufre.evt.gz', 'sw00010264046xwtw2sl_cl.evt.gz', 'sw00010264046xwtw2sl_uf.evt.gz', 'sw00010264046xwtw2sl_ufre.evt.gz', 'sw00010264046xwtw2st_cl.evt.gz', 'sw00010264046xwtw2st_uf.evt.gz', 'sw00010264046xwtw2st_ufre.evt.gz']
# ['sw00010264047xpcw3po_cl.evt.gz', 'sw00010264047xpcw3po_uf.evt.gz', 'sw00010264047xwtw2po_cl.evt.gz', 'sw00010264047xwtw2po_uf.evt.gz', 'sw00010264047xwtw2po_ufre.evt.gz', 'sw00010264047xwtw2sl_cl.evt.gz', 'sw00010264047xwtw2sl_uf.evt.gz', 'sw00010264047xwtw2sl_ufre.evt.gz', 'sw00010264047xwtw2st_cl.evt.gz', 'sw00010264047xwtw2st_uf.evt.gz', 'sw00010264047xwtw2st_ufre.evt.gz']
# ['sw00010264048xpcw3po_cl.evt.gz', 'sw00010264048xpcw3po_uf.evt.gz', 'sw00010264048xwtw2po_cl.evt.gz', 'sw00010264048xwtw2po_uf.evt.gz', 'sw00010264048xwtw2po_ufre.evt.gz', 'sw00010264048xwtw2sl_cl.evt.gz', 'sw00010264048xwtw2sl_uf.evt.gz', 'sw00010264048xwtw2sl_ufre.evt.gz', 'sw00010264048xwtw2st_cl.evt.gz', 'sw00010264048xwtw2st_uf.evt.gz', 'sw00010264048xwtw2st_ufre.evt.gz']
# ['sw00010264049xpcw3po_cl.evt.gz', 'sw00010264049xpcw3po_uf.evt.gz', 'sw00010264049xwtw2po_cl.evt.gz', 'sw00010264049xwtw2po_uf.evt.gz', 'sw00010264049xwtw2po_ufre.evt.gz', 'sw00010264049xwtw2sl_cl.evt.gz', 'sw00010264049xwtw2sl_uf.evt.gz', 'sw00010264049xwtw2sl_ufre.evt.gz', 'sw00010264049xwtw2st_cl.evt.gz', 'sw00010264049xwtw2st_uf.evt.gz', 'sw00010264049xwtw2st_ufre.evt.gz']
# ['sw00010264050xpcw3po_cl.evt.gz', 'sw00010264050xpcw3po_uf.evt.gz', 'sw00010264050xwtw2po_cl.evt.gz', 'sw00010264050xwtw2po_uf.evt.gz', 'sw00010264050xwtw2po_ufre.evt.gz', 'sw00010264050xwtw2sl_cl.evt.gz', 'sw00010264050xwtw2sl_uf.evt.gz', 'sw00010264050xwtw2sl_ufre.evt.gz', 'sw00010264050xwtw2st_cl.evt.gz', 'sw00010264050xwtw2st_uf.evt.gz', 'sw00010264050xwtw2st_ufre.evt.gz']
# ['sw00010264051xpcw3po_cl.evt.gz', 'sw00010264051xpcw3po_uf.evt.gz', 'sw00010264051xwtw2po_cl.evt.gz', 'sw00010264051xwtw2po_uf.evt.gz', 'sw00010264051xwtw2po_ufre.evt.gz', 'sw00010264051xwtw2sl_cl.evt.gz', 'sw00010264051xwtw2sl_uf.evt.gz', 'sw00010264051xwtw2sl_ufre.evt.gz', 'sw00010264051xwtw2st_cl.evt.gz', 'sw00010264051xwtw2st_uf.evt.gz', 'sw00010264051xwtw2st_ufre.evt.gz']
# ['sw00010264052xpcw3po_cl.evt.gz', 'sw00010264052xpcw3po_uf.evt.gz', 'sw00010264052xwtw2po_cl.evt.gz', 'sw00010264052xwtw2po_uf.evt.gz', 'sw00010264052xwtw2po_ufre.evt.gz', 'sw00010264052xwtw2sl_cl.evt.gz', 'sw00010264052xwtw2sl_uf.evt.gz', 'sw00010264052xwtw2sl_ufre.evt.gz', 'sw00010264052xwtw2st_cl.evt.gz', 'sw00010264052xwtw2st_uf.evt.gz', 'sw00010264052xwtw2st_ufre.evt.gz']
# ['sw00010264053xpcw3po_cl.evt.gz', 'sw00010264053xpcw3po_uf.evt.gz', 'sw00010264053xwtw2po_cl.evt.gz', 'sw00010264053xwtw2po_uf.evt.gz', 'sw00010264053xwtw2po_ufre.evt.gz', 'sw00010264053xwtw2sl_cl.evt.gz', 'sw00010264053xwtw2sl_uf.evt.gz', 'sw00010264053xwtw2sl_ufre.evt.gz', 'sw00010264053xwtw2st_cl.evt.gz', 'sw00010264053xwtw2st_uf.evt.gz', 'sw00010264053xwtw2st_ufre.evt.gz']
# ['sw00010264054xpcw3po_cl.evt.gz', 'sw00010264054xpcw3po_uf.evt.gz', 'sw00010264054xwtw2po_cl.evt.gz', 'sw00010264054xwtw2po_uf.evt.gz', 'sw00010264054xwtw2po_ufre.evt.gz', 'sw00010264054xwtw2sl_cl.evt.gz', 'sw00010264054xwtw2sl_uf.evt.gz', 'sw00010264054xwtw2sl_ufre.evt.gz', 'sw00010264054xwtw2st_cl.evt.gz', 'sw00010264054xwtw2st_uf.evt.gz', 'sw00010264054xwtw2st_ufre.evt.gz']
# ['sw00010264061xpcw3po_cl.evt.gz', 'sw00010264061xpcw3po_uf.evt.gz', 'sw00010264061xwtw2po_cl.evt.gz', 'sw00010264061xwtw2po_uf.evt.gz', 'sw00010264061xwtw2po_ufre.evt.gz', 'sw00010264061xwtw2sl_cl.evt.gz', 'sw00010264061xwtw2sl_uf.evt.gz', 'sw00010264061xwtw2sl_ufre.evt.gz', 'sw00010264061xwtw2st_cl.evt.gz', 'sw00010264061xwtw2st_uf.evt.gz', 'sw00010264061xwtw2st_ufre.evt.gz']
# ['sw00010264063xpcw3po_cl.evt.gz', 'sw00010264063xpcw3po_uf.evt.gz', 'sw00010264063xwtw2po_cl.evt.gz', 'sw00010264063xwtw2po_uf.evt.gz', 'sw00010264063xwtw2po_ufre.evt.gz', 'sw00010264063xwtw2sl_cl.evt.gz', 'sw00010264063xwtw2sl_uf.evt.gz', 'sw00010264063xwtw2sl_ufre.evt.gz', 'sw00010264063xwtw2st_cl.evt.gz', 'sw00010264063xwtw2st_uf.evt.gz', 'sw00010264063xwtw2st_ufre.evt.gz']
# ['sw00010264064xpcw3po_cl.evt.gz', 'sw00010264064xpcw3po_uf.evt.gz', 'sw00010264064xwtw2po_cl.evt.gz', 'sw00010264064xwtw2po_uf.evt.gz', 'sw00010264064xwtw2po_ufre.evt.gz', 'sw00010264064xwtw2sl_cl.evt.gz', 'sw00010264064xwtw2sl_uf.evt.gz', 'sw00010264064xwtw2sl_ufre.evt.gz', 'sw00010264064xwtw2st_cl.evt.gz', 'sw00010264064xwtw2st_uf.evt.gz', 'sw00010264064xwtw2st_ufre.evt.gz']
# ['sw00010264065xpcw3po_cl.evt.gz', 'sw00010264065xpcw3po_uf.evt.gz', 'sw00010264065xwtw2po_cl.evt.gz', 'sw00010264065xwtw2po_uf.evt.gz', 'sw00010264065xwtw2po_ufre.evt.gz', 'sw00010264065xwtw2sl_uf.evt.gz', 'sw00010264065xwtw2sl_ufre.evt.gz', 'sw00010264065xwtw2st_cl.evt.gz', 'sw00010264065xwtw2st_uf.evt.gz', 'sw00010264065xwtw2st_ufre.evt.gz']
# ['sw00010264066xpcw3po_cl.evt.gz', 'sw00010264066xpcw3po_uf.evt.gz', 'sw00010264066xwtw2po_cl.evt.gz', 'sw00010264066xwtw2po_uf.evt.gz', 'sw00010264066xwtw2po_ufre.evt.gz', 'sw00010264066xwtw2sl_cl.evt.gz', 'sw00010264066xwtw2sl_uf.evt.gz', 'sw00010264066xwtw2sl_ufre.evt.gz', 'sw00010264066xwtw2st_cl.evt.gz', 'sw00010264066xwtw2st_uf.evt.gz', 'sw00010264066xwtw2st_ufre.evt.gz']
# ['sw00010264067xpcw3po_cl.evt.gz', 'sw00010264067xpcw3po_uf.evt.gz', 'sw00010264067xwtw2po_cl.evt.gz', 'sw00010264067xwtw2po_uf.evt.gz', 'sw00010264067xwtw2po_ufre.evt.gz', 'sw00010264067xwtw2sl_cl.evt.gz', 'sw00010264067xwtw2sl_uf.evt.gz', 'sw00010264067xwtw2sl_ufre.evt.gz', 'sw00010264067xwtw2st_cl.evt.gz', 'sw00010264067xwtw2st_uf.evt.gz', 'sw00010264067xwtw2st_ufre.evt.gz']
# ['sw00010264068xpcw3po_cl.evt.gz', 'sw00010264068xpcw3po_uf.evt.gz', 'sw00010264068xwtw2po_cl.evt.gz', 'sw00010264068xwtw2po_uf.evt.gz', 'sw00010264068xwtw2po_ufre.evt.gz', 'sw00010264068xwtw2sl_cl.evt.gz', 'sw00010264068xwtw2sl_uf.evt.gz', 'sw00010264068xwtw2sl_ufre.evt.gz', 'sw00010264068xwtw2st_cl.evt.gz', 'sw00010264068xwtw2st_uf.evt.gz', 'sw00010264068xwtw2st_ufre.evt.gz']
# ['sw00010264071xpcw3po_cl.evt.gz', 'sw00010264071xpcw3po_uf.evt.gz', 'sw00010264071xwtw2po_cl.evt.gz', 'sw00010264071xwtw2po_uf.evt.gz', 'sw00010264071xwtw2po_ufre.evt.gz', 'sw00010264071xwtw2sl_cl.evt.gz', 'sw00010264071xwtw2sl_uf.evt.gz', 'sw00010264071xwtw2sl_ufre.evt.gz', 'sw00010264071xwtw2st_cl.evt.gz', 'sw00010264071xwtw2st_uf.evt.gz', 'sw00010264071xwtw2st_ufre.evt.gz']
# ['sw00010264072xpcw3po_cl.evt.gz', 'sw00010264072xpcw3po_uf.evt.gz', 'sw00010264072xwtw2po_cl.evt.gz', 'sw00010264072xwtw2po_uf.evt.gz', 'sw00010264072xwtw2po_ufre.evt.gz', 'sw00010264072xwtw2sl_cl.evt.gz', 'sw00010264072xwtw2sl_uf.evt.gz', 'sw00010264072xwtw2sl_ufre.evt.gz', 'sw00010264072xwtw2st_cl.evt.gz', 'sw00010264072xwtw2st_uf.evt.gz', 'sw00010264072xwtw2st_ufre.evt.gz']
# ['sw00010264073xpcw3po_cl.evt.gz', 'sw00010264073xpcw3po_uf.evt.gz', 'sw00010264073xwtw2po_cl.evt.gz', 'sw00010264073xwtw2po_uf.evt.gz', 'sw00010264073xwtw2po_ufre.evt.gz', 'sw00010264073xwtw2sl_cl.evt.gz', 'sw00010264073xwtw2sl_uf.evt.gz', 'sw00010264073xwtw2sl_ufre.evt.gz', 'sw00010264073xwtw2st_cl.evt.gz', 'sw00010264073xwtw2st_uf.evt.gz', 'sw00010264073xwtw2st_ufre.evt.gz']
# ['sw00010264074xpcw3po_cl.evt.gz', 'sw00010264074xpcw3po_uf.evt.gz', 'sw00010264074xwtw2po_cl.evt.gz', 'sw00010264074xwtw2po_uf.evt.gz', 'sw00010264074xwtw2po_ufre.evt.gz', 'sw00010264074xwtw2sl_cl.evt.gz', 'sw00010264074xwtw2sl_uf.evt.gz', 'sw00010264074xwtw2sl_ufre.evt.gz', 'sw00010264074xwtw2st_cl.evt.gz', 'sw00010264074xwtw2st_uf.evt.gz', 'sw00010264074xwtw2st_ufre.evt.gz']
# ['sw00010264075xpcw3po_cl.evt.gz', 'sw00010264075xpcw3po_uf.evt.gz', 'sw00010264075xwtw2po_cl.evt.gz', 'sw00010264075xwtw2po_uf.evt.gz', 'sw00010264075xwtw2po_ufre.evt.gz', 'sw00010264075xwtw2sl_cl.evt.gz', 'sw00010264075xwtw2sl_uf.evt.gz', 'sw00010264075xwtw2sl_ufre.evt.gz', 'sw00010264075xwtw2st_cl.evt.gz', 'sw00010264075xwtw2st_uf.evt.gz', 'sw00010264075xwtw2st_ufre.evt.gz']
# ['sw00010264076xpcw3po_cl.evt.gz', 'sw00010264076xpcw3po_uf.evt.gz', 'sw00010264076xwtw2po_cl.evt.gz', 'sw00010264076xwtw2po_uf.evt.gz', 'sw00010264076xwtw2po_ufre.evt.gz', 'sw00010264076xwtw2sl_cl.evt.gz', 'sw00010264076xwtw2sl_uf.evt.gz', 'sw00010264076xwtw2sl_ufre.evt.gz', 'sw00010264076xwtw2st_cl.evt.gz', 'sw00010264076xwtw2st_uf.evt.gz', 'sw00010264076xwtw2st_ufre.evt.gz']
# ['sw00010264077xpcw3po_cl.evt.gz', 'sw00010264077xpcw3po_uf.evt.gz', 'sw00010264077xwtw2po_cl.evt.gz', 'sw00010264077xwtw2po_uf.evt.gz', 'sw00010264077xwtw2po_ufre.evt.gz', 'sw00010264077xwtw2sl_cl.evt.gz', 'sw00010264077xwtw2sl_uf.evt.gz', 'sw00010264077xwtw2sl_ufre.evt.gz', 'sw00010264077xwtw2st_cl.evt.gz', 'sw00010264077xwtw2st_uf.evt.gz', 'sw00010264077xwtw2st_ufre.evt.gz']
# ['sw00010264079xpcw3po_cl.evt.gz', 'sw00010264079xpcw3po_uf.evt.gz', 'sw00010264079xwtw2po_cl.evt.gz', 'sw00010264079xwtw2po_uf.evt.gz', 'sw00010264079xwtw2po_ufre.evt.gz', 'sw00010264079xwtw2sl_cl.evt.gz', 'sw00010264079xwtw2sl_uf.evt.gz', 'sw00010264079xwtw2sl_ufre.evt.gz', 'sw00010264079xwtw2st_cl.evt.gz', 'sw00010264079xwtw2st_uf.evt.gz', 'sw00010264079xwtw2st_ufre.evt.gz']
# ['sw00010264080xpcw3po_cl.evt.gz', 'sw00010264080xpcw3po_uf.evt.gz', 'sw00010264080xwtw2po_cl.evt.gz', 'sw00010264080xwtw2po_uf.evt.gz', 'sw00010264080xwtw2po_ufre.evt.gz', 'sw00010264080xwtw2sl_cl.evt.gz', 'sw00010264080xwtw2sl_uf.evt.gz', 'sw00010264080xwtw2sl_ufre.evt.gz', 'sw00010264080xwtw2st_cl.evt.gz', 'sw00010264080xwtw2st_uf.evt.gz', 'sw00010264080xwtw2st_ufre.evt.gz']
# ['sw00010264081xpcw3po_cl.evt.gz', 'sw00010264081xpcw3po_uf.evt.gz', 'sw00010264081xwtw2po_cl.evt.gz', 'sw00010264081xwtw2po_uf.evt.gz', 'sw00010264081xwtw2po_ufre.evt.gz', 'sw00010264081xwtw2sl_cl.evt.gz', 'sw00010264081xwtw2sl_uf.evt.gz', 'sw00010264081xwtw2sl_ufre.evt.gz', 'sw00010264081xwtw2st_cl.evt.gz', 'sw00010264081xwtw2st_uf.evt.gz', 'sw00010264081xwtw2st_ufre.evt.gz']
# ['sw00010264082xpcw3po_cl.evt.gz', 'sw00010264082xpcw3po_uf.evt.gz', 'sw00010264082xwtw2po_cl.evt.gz', 'sw00010264082xwtw2po_uf.evt.gz', 'sw00010264082xwtw2po_ufre.evt.gz', 'sw00010264082xwtw2st_cl.evt.gz', 'sw00010264082xwtw2st_uf.evt.gz', 'sw00010264082xwtw2st_ufre.evt.gz']
# ['sw00010264083xpcw3po_cl.evt.gz', 'sw00010264083xpcw3po_uf.evt.gz', 'sw00010264083xwtw2po_cl.evt.gz', 'sw00010264083xwtw2po_uf.evt.gz', 'sw00010264083xwtw2po_ufre.evt.gz', 'sw00010264083xwtw2sl_cl.evt.gz', 'sw00010264083xwtw2sl_uf.evt.gz', 'sw00010264083xwtw2sl_ufre.evt.gz', 'sw00010264083xwtw2st_cl.evt.gz', 'sw00010264083xwtw2st_uf.evt.gz', 'sw00010264083xwtw2st_ufre.evt.gz']
# ['sw00010264084xpcw3po_cl.evt.gz', 'sw00010264084xpcw3po_uf.evt.gz', 'sw00010264084xwtw2po_cl.evt.gz', 'sw00010264084xwtw2po_uf.evt.gz', 'sw00010264084xwtw2po_ufre.evt.gz', 'sw00010264084xwtw2sl_cl.evt.gz', 'sw00010264084xwtw2sl_uf.evt.gz', 'sw00010264084xwtw2sl_ufre.evt.gz', 'sw00010264084xwtw2st_cl.evt.gz', 'sw00010264084xwtw2st_uf.evt.gz', 'sw00010264084xwtw2st_ufre.evt.gz']
# ['sw00010264085xpcw3po_cl.evt.gz', 'sw00010264085xpcw3po_uf.evt.gz', 'sw00010264085xwtw2po_cl.evt.gz', 'sw00010264085xwtw2po_uf.evt.gz', 'sw00010264085xwtw2po_ufre.evt.gz', 'sw00010264085xwtw2sl_cl.evt.gz', 'sw00010264085xwtw2sl_uf.evt.gz', 'sw00010264085xwtw2sl_ufre.evt.gz', 'sw00010264085xwtw2st_cl.evt.gz', 'sw00010264085xwtw2st_uf.evt.gz', 'sw00010264085xwtw2st_ufre.evt.gz']
# ['sw00010264086xpcw3po_cl.evt.gz', 'sw00010264086xpcw3po_uf.evt.gz', 'sw00010264086xwtw2po_cl.evt.gz', 'sw00010264086xwtw2po_uf.evt.gz', 'sw00010264086xwtw2po_ufre.evt.gz', 'sw00010264086xwtw2sl_cl.evt.gz', 'sw00010264086xwtw2sl_uf.evt.gz', 'sw00010264086xwtw2sl_ufre.evt.gz', 'sw00010264086xwtw2st_cl.evt.gz', 'sw00010264086xwtw2st_uf.evt.gz', 'sw00010264086xwtw2st_ufre.evt.gz']
# ['sw00010264087xpcw3po_cl.evt.gz', 'sw00010264087xpcw3po_uf.evt.gz', 'sw00010264087xwtw2po_cl.evt.gz', 'sw00010264087xwtw2po_uf.evt.gz', 'sw00010264087xwtw2po_ufre.evt.gz', 'sw00010264087xwtw2sl_cl.evt.gz', 'sw00010264087xwtw2sl_uf.evt.gz', 'sw00010264087xwtw2sl_ufre.evt.gz', 'sw00010264087xwtw2st_cl.evt.gz', 'sw00010264087xwtw2st_uf.evt.gz', 'sw00010264087xwtw2st_ufre.evt.gz']
# ['sw00010264088xpcw3po_cl.evt.gz', 'sw00010264088xpcw3po_uf.evt.gz', 'sw00010264088xwtw2po_cl.evt.gz', 'sw00010264088xwtw2po_uf.evt.gz', 'sw00010264088xwtw2po_ufre.evt.gz', 'sw00010264088xwtw2sl_cl.evt.gz', 'sw00010264088xwtw2sl_uf.evt.gz', 'sw00010264088xwtw2sl_ufre.evt.gz', 'sw00010264088xwtw2st_cl.evt.gz', 'sw00010264088xwtw2st_uf.evt.gz', 'sw00010264088xwtw2st_ufre.evt.gz']
# ['sw00010264089xpcw3po_cl.evt.gz', 'sw00010264089xpcw3po_uf.evt.gz', 'sw00010264089xwtw2po_uf.evt.gz', 'sw00010264089xwtw2po_ufre.evt.gz', 'sw00010264089xwtw2sl_cl.evt.gz', 'sw00010264089xwtw2sl_uf.evt.gz', 'sw00010264089xwtw2sl_ufre.evt.gz', 'sw00010264089xwtw2st_cl.evt.gz', 'sw00010264089xwtw2st_uf.evt.gz', 'sw00010264089xwtw2st_ufre.evt.gz']
# ['sw00010264090xpcw3po_cl.evt.gz', 'sw00010264090xpcw3po_uf.evt.gz', 'sw00010264090xwtw2po_cl.evt.gz', 'sw00010264090xwtw2po_uf.evt.gz', 'sw00010264090xwtw2po_ufre.evt.gz', 'sw00010264090xwtw2sl_cl.evt.gz', 'sw00010264090xwtw2sl_uf.evt.gz', 'sw00010264090xwtw2sl_ufre.evt.gz', 'sw00010264090xwtw2st_cl.evt.gz', 'sw00010264090xwtw2st_uf.evt.gz', 'sw00010264090xwtw2st_ufre.evt.gz']
# ['sw00010264092xpcw3po_cl.evt.gz', 'sw00010264092xpcw3po_uf.evt.gz', 'sw00010264092xwtw2po_cl.evt.gz', 'sw00010264092xwtw2po_uf.evt.gz', 'sw00010264092xwtw2po_ufre.evt.gz', 'sw00010264092xwtw2sl_cl.evt.gz', 'sw00010264092xwtw2sl_uf.evt.gz', 'sw00010264092xwtw2sl_ufre.evt.gz', 'sw00010264092xwtw2st_cl.evt.gz', 'sw00010264092xwtw2st_uf.evt.gz', 'sw00010264092xwtw2st_ufre.evt.gz']
# ['sw00010264093xpcw3po_cl.evt.gz', 'sw00010264093xpcw3po_uf.evt.gz', 'sw00010264093xwtw2po_cl.evt.gz', 'sw00010264093xwtw2po_uf.evt.gz', 'sw00010264093xwtw2po_ufre.evt.gz', 'sw00010264093xwtw2sl_cl.evt.gz', 'sw00010264093xwtw2sl_uf.evt.gz', 'sw00010264093xwtw2sl_ufre.evt.gz', 'sw00010264093xwtw2st_cl.evt.gz', 'sw00010264093xwtw2st_uf.evt.gz', 'sw00010264093xwtw2st_ufre.evt.gz']
# ['sw00010264094xpcw3po_cl.evt.gz', 'sw00010264094xpcw3po_uf.evt.gz', 'sw00010264094xwtw2po_uf.evt.gz', 'sw00010264094xwtw2po_ufre.evt.gz', 'sw00010264094xwtw2sl_cl.evt.gz', 'sw00010264094xwtw2sl_uf.evt.gz', 'sw00010264094xwtw2sl_ufre.evt.gz', 'sw00010264094xwtw2st_cl.evt.gz', 'sw00010264094xwtw2st_uf.evt.gz', 'sw00010264094xwtw2st_ufre.evt.gz']
# ['sw00010264095xpcw3po_cl.evt.gz', 'sw00010264095xpcw3po_uf.evt.gz', 'sw00010264095xwtw2po_cl.evt.gz', 'sw00010264095xwtw2po_uf.evt.gz', 'sw00010264095xwtw2po_ufre.evt.gz', 'sw00010264095xwtw2sl_cl.evt.gz', 'sw00010264095xwtw2sl_uf.evt.gz', 'sw00010264095xwtw2sl_ufre.evt.gz', 'sw00010264095xwtw2st_cl.evt.gz', 'sw00010264095xwtw2st_uf.evt.gz', 'sw00010264095xwtw2st_ufre.evt.gz']
# ['sw00010264097xpcw3po_cl.evt.gz', 'sw00010264097xpcw3po_uf.evt.gz', 'sw00010264097xwtw2po_cl.evt.gz', 'sw00010264097xwtw2po_uf.evt.gz', 'sw00010264097xwtw2po_ufre.evt.gz', 'sw00010264097xwtw2sl_cl.evt.gz', 'sw00010264097xwtw2sl_uf.evt.gz', 'sw00010264097xwtw2sl_ufre.evt.gz', 'sw00010264097xwtw2st_cl.evt.gz', 'sw00010264097xwtw2st_uf.evt.gz', 'sw00010264097xwtw2st_ufre.evt.gz']
# ['sw00010264098xpcw3po_cl.evt.gz', 'sw00010264098xpcw3po_uf.evt.gz', 'sw00010264098xwtw2po_cl.evt.gz', 'sw00010264098xwtw2po_uf.evt.gz', 'sw00010264098xwtw2po_ufre.evt.gz', 'sw00010264098xwtw2sl_cl.evt.gz', 'sw00010264098xwtw2sl_uf.evt.gz', 'sw00010264098xwtw2sl_ufre.evt.gz', 'sw00010264098xwtw2st_cl.evt.gz', 'sw00010264098xwtw2st_uf.evt.gz', 'sw00010264098xwtw2st_ufre.evt.gz']
# ['sw00010264099xpcw3po_cl.evt.gz', 'sw00010264099xpcw3po_uf.evt.gz', 'sw00010264099xwtw2po_cl.evt.gz', 'sw00010264099xwtw2po_uf.evt.gz', 'sw00010264099xwtw2po_ufre.evt.gz', 'sw00010264099xwtw2sl_cl.evt.gz', 'sw00010264099xwtw2sl_uf.evt.gz', 'sw00010264099xwtw2sl_ufre.evt.gz', 'sw00010264099xwtw2st_cl.evt.gz', 'sw00010264099xwtw2st_uf.evt.gz', 'sw00010264099xwtw2st_ufre.evt.gz']
# ['sw00010264100xpcw3po_cl.evt.gz', 'sw00010264100xpcw3po_uf.evt.gz', 'sw00010264100xwtw2po_cl.evt.gz', 'sw00010264100xwtw2po_uf.evt.gz', 'sw00010264100xwtw2po_ufre.evt.gz', 'sw00010264100xwtw2sl_cl.evt.gz', 'sw00010264100xwtw2sl_uf.evt.gz', 'sw00010264100xwtw2sl_ufre.evt.gz', 'sw00010264100xwtw2st_cl.evt.gz', 'sw00010264100xwtw2st_uf.evt.gz', 'sw00010264100xwtw2st_ufre.evt.gz']
# ['sw00010264101xpcw3po_cl.evt.gz', 'sw00010264101xpcw3po_uf.evt.gz', 'sw00010264101xwtw2po_cl.evt.gz', 'sw00010264101xwtw2po_uf.evt.gz', 'sw00010264101xwtw2po_ufre.evt.gz', 'sw00010264101xwtw2st_cl.evt.gz', 'sw00010264101xwtw2st_uf.evt.gz', 'sw00010264101xwtw2st_ufre.evt.gz']
# ['sw00010264102xpcw3po_cl.evt.gz', 'sw00010264102xpcw3po_uf.evt.gz', 'sw00010264102xwtw2po_cl.evt.gz', 'sw00010264102xwtw2po_uf.evt.gz', 'sw00010264102xwtw2po_ufre.evt.gz', 'sw00010264102xwtw2sl_cl.evt.gz', 'sw00010264102xwtw2sl_uf.evt.gz', 'sw00010264102xwtw2sl_ufre.evt.gz', 'sw00010264102xwtw2st_cl.evt.gz', 'sw00010264102xwtw2st_uf.evt.gz', 'sw00010264102xwtw2st_ufre.evt.gz']
# ['sw00010264103xpcw3po_cl.evt.gz', 'sw00010264103xpcw3po_uf.evt.gz', 'sw00010264103xwtw2po_cl.evt.gz', 'sw00010264103xwtw2po_uf.evt.gz', 'sw00010264103xwtw2po_ufre.evt.gz', 'sw00010264103xwtw2sl_cl.evt.gz', 'sw00010264103xwtw2sl_uf.evt.gz', 'sw00010264103xwtw2sl_ufre.evt.gz', 'sw00010264103xwtw2st_cl.evt.gz', 'sw00010264103xwtw2st_uf.evt.gz', 'sw00010264103xwtw2st_ufre.evt.gz']
# ['sw00010264104xpcw3po_cl.evt.gz', 'sw00010264104xpcw3po_uf.evt.gz', 'sw00010264104xwtw2po_cl.evt.gz', 'sw00010264104xwtw2po_uf.evt.gz', 'sw00010264104xwtw2po_ufre.evt.gz', 'sw00010264104xwtw2sl_cl.evt.gz', 'sw00010264104xwtw2sl_uf.evt.gz', 'sw00010264104xwtw2sl_ufre.evt.gz', 'sw00010264104xwtw2st_cl.evt.gz', 'sw00010264104xwtw2st_uf.evt.gz', 'sw00010264104xwtw2st_ufre.evt.gz']
# ['sw00010264105xpcw3po_cl.evt.gz', 'sw00010264105xpcw3po_uf.evt.gz', 'sw00010264105xwtw2po_cl.evt.gz', 'sw00010264105xwtw2po_uf.evt.gz', 'sw00010264105xwtw2po_ufre.evt.gz', 'sw00010264105xwtw2sl_cl.evt.gz', 'sw00010264105xwtw2sl_uf.evt.gz', 'sw00010264105xwtw2sl_ufre.evt.gz', 'sw00010264105xwtw2st_cl.evt.gz', 'sw00010264105xwtw2st_uf.evt.gz', 'sw00010264105xwtw2st_ufre.evt.gz']
# ['sw00010264106xpcw3po_cl.evt.gz', 'sw00010264106xpcw3po_uf.evt.gz', 'sw00010264106xwtw2po_cl.evt.gz', 'sw00010264106xwtw2po_uf.evt.gz', 'sw00010264106xwtw2po_ufre.evt.gz', 'sw00010264106xwtw2sl_cl.evt.gz', 'sw00010264106xwtw2sl_uf.evt.gz', 'sw00010264106xwtw2sl_ufre.evt.gz', 'sw00010264106xwtw2st_cl.evt.gz', 'sw00010264106xwtw2st_uf.evt.gz', 'sw00010264106xwtw2st_ufre.evt.gz']
# ['sw00010264107xpcw3po_cl.evt.gz', 'sw00010264107xpcw3po_uf.evt.gz', 'sw00010264107xwtw2po_cl.evt.gz', 'sw00010264107xwtw2po_uf.evt.gz', 'sw00010264107xwtw2po_ufre.evt.gz', 'sw00010264107xwtw2sl_cl.evt.gz', 'sw00010264107xwtw2sl_uf.evt.gz', 'sw00010264107xwtw2sl_ufre.evt.gz', 'sw00010264107xwtw2st_cl.evt.gz', 'sw00010264107xwtw2st_uf.evt.gz', 'sw00010264107xwtw2st_ufre.evt.gz']
# ['sw00010264108xpcw3po_cl.evt.gz', 'sw00010264108xpcw3po_uf.evt.gz', 'sw00010264108xwtw2po_cl.evt.gz', 'sw00010264108xwtw2po_uf.evt.gz', 'sw00010264108xwtw2po_ufre.evt.gz', 'sw00010264108xwtw2sl_cl.evt.gz', 'sw00010264108xwtw2sl_uf.evt.gz', 'sw00010264108xwtw2sl_ufre.evt.gz', 'sw00010264108xwtw2st_cl.evt.gz', 'sw00010264108xwtw2st_uf.evt.gz', 'sw00010264108xwtw2st_ufre.evt.gz']
# ['sw00010264109xpcw3po_cl.evt.gz', 'sw00010264109xpcw3po_uf.evt.gz', 'sw00010264109xwtw2po_cl.evt.gz', 'sw00010264109xwtw2po_uf.evt.gz', 'sw00010264109xwtw2po_ufre.evt.gz', 'sw00010264109xwtw2sl_cl.evt.gz', 'sw00010264109xwtw2sl_uf.evt.gz', 'sw00010264109xwtw2sl_ufre.evt.gz', 'sw00010264109xwtw2st_cl.evt.gz', 'sw00010264109xwtw2st_uf.evt.gz', 'sw00010264109xwtw2st_ufre.evt.gz']
# ['sw00010264110xpcw3po_cl.evt.gz', 'sw00010264110xpcw3po_uf.evt.gz', 'sw00010264110xwtw2po_cl.evt.gz', 'sw00010264110xwtw2po_uf.evt.gz', 'sw00010264110xwtw2po_ufre.evt.gz', 'sw00010264110xwtw2sl_cl.evt.gz', 'sw00010264110xwtw2sl_uf.evt.gz', 'sw00010264110xwtw2sl_ufre.evt.gz', 'sw00010264110xwtw2st_cl.evt.gz', 'sw00010264110xwtw2st_uf.evt.gz', 'sw00010264110xwtw2st_ufre.evt.gz']
# ['sw00010264111xpcw3po_cl.evt.gz', 'sw00010264111xpcw3po_uf.evt.gz', 'sw00010264111xwtw2po_cl.evt.gz', 'sw00010264111xwtw2po_uf.evt.gz', 'sw00010264111xwtw2po_ufre.evt.gz', 'sw00010264111xwtw2sl_cl.evt.gz', 'sw00010264111xwtw2sl_uf.evt.gz', 'sw00010264111xwtw2sl_ufre.evt.gz', 'sw00010264111xwtw2st_cl.evt.gz', 'sw00010264111xwtw2st_uf.evt.gz', 'sw00010264111xwtw2st_ufre.evt.gz']
# ['sw00010264112xpcw3po_cl.evt.gz', 'sw00010264112xpcw3po_uf.evt.gz', 'sw00010264112xwtw2po_cl.evt.gz', 'sw00010264112xwtw2po_uf.evt.gz', 'sw00010264112xwtw2po_ufre.evt.gz', 'sw00010264112xwtw2sl_cl.evt.gz', 'sw00010264112xwtw2sl_uf.evt.gz', 'sw00010264112xwtw2sl_ufre.evt.gz', 'sw00010264112xwtw2st_cl.evt.gz', 'sw00010264112xwtw2st_uf.evt.gz', 'sw00010264112xwtw2st_ufre.evt.gz']
# ['sw00010264113xpcw3po_cl.evt.gz', 'sw00010264113xpcw3po_uf.evt.gz', 'sw00010264113xwtw2po_cl.evt.gz', 'sw00010264113xwtw2po_uf.evt.gz', 'sw00010264113xwtw2po_ufre.evt.gz', 'sw00010264113xwtw2sl_cl.evt.gz', 'sw00010264113xwtw2sl_uf.evt.gz', 'sw00010264113xwtw2sl_ufre.evt.gz', 'sw00010264113xwtw2st_cl.evt.gz', 'sw00010264113xwtw2st_uf.evt.gz', 'sw00010264113xwtw2st_ufre.evt.gz']
# ['sw00010264114xpcw3po_cl.evt.gz', 'sw00010264114xpcw3po_uf.evt.gz', 'sw00010264114xwtw2po_cl.evt.gz', 'sw00010264114xwtw2po_uf.evt.gz', 'sw00010264114xwtw2po_ufre.evt.gz', 'sw00010264114xwtw2sl_cl.evt.gz', 'sw00010264114xwtw2sl_uf.evt.gz', 'sw00010264114xwtw2sl_ufre.evt.gz', 'sw00010264114xwtw2st_cl.evt.gz', 'sw00010264114xwtw2st_uf.evt.gz', 'sw00010264114xwtw2st_ufre.evt.gz']
# ['sw00010264115xpcw3po_cl.evt.gz', 'sw00010264115xpcw3po_uf.evt.gz', 'sw00010264115xwtw2po_cl.evt.gz', 'sw00010264115xwtw2po_uf.evt.gz', 'sw00010264115xwtw2po_ufre.evt.gz', 'sw00010264115xwtw2sl_cl.evt.gz', 'sw00010264115xwtw2sl_uf.evt.gz', 'sw00010264115xwtw2sl_ufre.evt.gz', 'sw00010264115xwtw2st_cl.evt.gz', 'sw00010264115xwtw2st_uf.evt.gz', 'sw00010264115xwtw2st_ufre.evt.gz']
# ['sw00010264116xpcw3po_cl.evt.gz', 'sw00010264116xpcw3po_uf.evt.gz', 'sw00010264116xwtw2po_cl.evt.gz', 'sw00010264116xwtw2po_uf.evt.gz', 'sw00010264116xwtw2po_ufre.evt.gz', 'sw00010264116xwtw2sl_cl.evt.gz', 'sw00010264116xwtw2sl_uf.evt.gz', 'sw00010264116xwtw2sl_ufre.evt.gz', 'sw00010264116xwtw2st_cl.evt.gz', 'sw00010264116xwtw2st_uf.evt.gz', 'sw00010264116xwtw2st_ufre.evt.gz']
# ['sw00010264117xpcw3po_cl.evt.gz', 'sw00010264117xpcw3po_uf.evt.gz', 'sw00010264117xpcw3sl_cl.evt.gz', 'sw00010264117xpcw3sl_uf.evt.gz', 'sw00010264117xpcw3st_cl.evt.gz', 'sw00010264117xpcw3st_uf.evt.gz', 'sw00010264117xwtw2po_cl.evt.gz', 'sw00010264117xwtw2po_uf.evt.gz', 'sw00010264117xwtw2po_ufre.evt.gz']
# ['sw00010264119xpcw3po_cl.evt.gz', 'sw00010264119xpcw3po_uf.evt.gz', 'sw00010264119xwtw2po_cl.evt.gz', 'sw00010264119xwtw2po_uf.evt.gz', 'sw00010264119xwtw2po_ufre.evt.gz', 'sw00010264119xwtw2sl_cl.evt.gz', 'sw00010264119xwtw2sl_uf.evt.gz', 'sw00010264119xwtw2sl_ufre.evt.gz', 'sw00010264119xwtw2st_cl.evt.gz', 'sw00010264119xwtw2st_uf.evt.gz', 'sw00010264119xwtw2st_ufre.evt.gz']
# ['sw00010264120xpcw3po_cl.evt.gz', 'sw00010264120xpcw3po_uf.evt.gz', 'sw00010264120xwtw2sl_cl.evt.gz', 'sw00010264120xwtw2sl_uf.evt.gz', 'sw00010264120xwtw2sl_ufre.evt.gz', 'sw00010264120xwtw2st_cl.evt.gz', 'sw00010264120xwtw2st_uf.evt.gz', 'sw00010264120xwtw2st_ufre.evt.gz']
# ['sw00010264121xpcw3po_cl.evt.gz', 'sw00010264121xpcw3po_uf.evt.gz', 'sw00010264121xwtw2po_cl.evt.gz', 'sw00010264121xwtw2po_uf.evt.gz', 'sw00010264121xwtw2po_ufre.evt.gz', 'sw00010264121xwtw2sl_cl.evt.gz', 'sw00010264121xwtw2sl_uf.evt.gz', 'sw00010264121xwtw2sl_ufre.evt.gz', 'sw00010264121xwtw2st_cl.evt.gz', 'sw00010264121xwtw2st_uf.evt.gz', 'sw00010264121xwtw2st_ufre.evt.gz']
# ['sw00010264122xpcw3po_cl.evt.gz', 'sw00010264122xpcw3po_uf.evt.gz', 'sw00010264122xwtw2po_cl.evt.gz', 'sw00010264122xwtw2po_uf.evt.gz', 'sw00010264122xwtw2po_ufre.evt.gz', 'sw00010264122xwtw2sl_cl.evt.gz', 'sw00010264122xwtw2sl_uf.evt.gz', 'sw00010264122xwtw2sl_ufre.evt.gz', 'sw00010264122xwtw2st_cl.evt.gz', 'sw00010264122xwtw2st_uf.evt.gz', 'sw00010264122xwtw2st_ufre.evt.gz']
# ['sw00010264123xpcw3po_cl.evt.gz', 'sw00010264123xpcw3po_uf.evt.gz', 'sw00010264123xwtw2po_cl.evt.gz', 'sw00010264123xwtw2po_uf.evt.gz', 'sw00010264123xwtw2po_ufre.evt.gz', 'sw00010264123xwtw2st_cl.evt.gz', 'sw00010264123xwtw2st_uf.evt.gz', 'sw00010264123xwtw2st_ufre.evt.gz']
# ['sw00010331001xpcw3po_cl.evt.gz', 'sw00010331001xpcw3po_uf.evt.gz', 'sw00010331001xwtw2sl_cl.evt.gz', 'sw00010331001xwtw2sl_uf.evt.gz', 'sw00010331001xwtw2sl_ufre.evt.gz', 'sw00010331001xwtw2st_cl.evt.gz', 'sw00010331001xwtw2st_uf.evt.gz', 'sw00010331001xwtw2st_ufre.evt.gz']
# ['sw00010331002xpcw3po_cl.evt.gz', 'sw00010331002xpcw3po_uf.evt.gz', 'sw00010331002xwtw2st_cl.evt.gz', 'sw00010331002xwtw2st_uf.evt.gz', 'sw00010331002xwtw2st_ufre.evt.gz']
# ['sw00010331003xpcw3po_cl.evt.gz', 'sw00010331003xpcw3po_uf.evt.gz', 'sw00010331003xwtw2sl_cl.evt.gz', 'sw00010331003xwtw2sl_uf.evt.gz', 'sw00010331003xwtw2sl_ufre.evt.gz', 'sw00010331003xwtw2st_cl.evt.gz', 'sw00010331003xwtw2st_uf.evt.gz', 'sw00010331003xwtw2st_ufre.evt.gz']
# ['sw00010331004xpcw3po_cl.evt.gz', 'sw00010331004xpcw3po_uf.evt.gz', 'sw00010331004xwtw2st_cl.evt.gz', 'sw00010331004xwtw2st_uf.evt.gz', 'sw00010331004xwtw2st_ufre.evt.gz']
# ['sw00010364001xpcw3po_cl.evt.gz', 'sw00010364001xpcw3po_uf.evt.gz', 'sw00010364001xwtw2sl_cl.evt.gz', 'sw00010364001xwtw2sl_uf.evt.gz', 'sw00010364001xwtw2sl_ufre.evt.gz', 'sw00010364001xwtw2st_cl.evt.gz', 'sw00010364001xwtw2st_uf.evt.gz', 'sw00010364001xwtw2st_ufre.evt.gz']
# ['sw00010364003xpcw3po_cl.evt.gz', 'sw00010364003xpcw3po_uf.evt.gz', 'sw00010364003xwtw2sl_cl.evt.gz', 'sw00010364003xwtw2sl_uf.evt.gz', 'sw00010364003xwtw2sl_ufre.evt.gz', 'sw00010364003xwtw2st_cl.evt.gz', 'sw00010364003xwtw2st_uf.evt.gz', 'sw00010364003xwtw2st_ufre.evt.gz']
# ['sw00010385001xpcw3po_cl.evt.gz', 'sw00010385001xpcw3po_uf.evt.gz', 'sw00010385001xwtw2st_cl.evt.gz', 'sw00010385001xwtw2st_uf.evt.gz', 'sw00010385001xwtw2st_ufre.evt.gz']
# ['sw00010385002xpcw3po_cl.evt.gz', 'sw00010385002xpcw3po_uf.evt.gz', 'sw00010385002xwtw2sl_cl.evt.gz', 'sw00010385002xwtw2sl_uf.evt.gz', 'sw00010385002xwtw2sl_ufre.evt.gz', 'sw00010385002xwtw2st_cl.evt.gz', 'sw00010385002xwtw2st_uf.evt.gz', 'sw00010385002xwtw2st_ufre.evt.gz']
# ['sw00010385003xpcw3po_cl.evt.gz', 'sw00010385003xpcw3po_uf.evt.gz', 'sw00010385003xwtw2sl_cl.evt.gz', 'sw00010385003xwtw2sl_uf.evt.gz', 'sw00010385003xwtw2sl_ufre.evt.gz', 'sw00010385003xwtw2st_cl.evt.gz', 'sw00010385003xwtw2st_uf.evt.gz', 'sw00010385003xwtw2st_ufre.evt.gz']
# ['sw00010385004xpcw3po_cl.evt.gz', 'sw00010385004xpcw3po_uf.evt.gz', 'sw00010385004xwtw2st_cl.evt.gz', 'sw00010385004xwtw2st_uf.evt.gz', 'sw00010385004xwtw2st_ufre.evt.gz']
# ['sw00010491001xpcw3po_cl.evt.gz', 'sw00010491001xpcw3po_uf.evt.gz', 'sw00010491001xwtw2st_cl.evt.gz', 'sw00010491001xwtw2st_uf.evt.gz', 'sw00010491001xwtw2st_ufre.evt.gz']
# ['sw00010492001xpcw3po_cl.evt.gz', 'sw00010492001xpcw3po_uf.evt.gz', 'sw00010492001xwtw2st_cl.evt.gz', 'sw00010492001xwtw2st_uf.evt.gz', 'sw00010492001xwtw2st_ufre.evt.gz']
# ['sw00010493001xpcw3po_cl.evt.gz', 'sw00010493001xpcw3po_uf.evt.gz', 'sw00010493001xwtw2st_cl.evt.gz', 'sw00010493001xwtw2st_uf.evt.gz', 'sw00010493001xwtw2st_ufre.evt.gz']
# ['sw00010494001xpcw3po_cl.evt.gz', 'sw00010494001xpcw3po_uf.evt.gz', 'sw00010494001xwtw2st_cl.evt.gz', 'sw00010494001xwtw2st_uf.evt.gz', 'sw00010494001xwtw2st_ufre.evt.gz']
# ['sw00010495001xpcw3po_cl.evt.gz', 'sw00010495001xpcw3po_uf.evt.gz', 'sw00010495001xwtw2st_cl.evt.gz', 'sw00010495001xwtw2st_uf.evt.gz', 'sw00010495001xwtw2st_ufre.evt.gz']
# ['sw00010496001xpcw3po_cl.evt.gz', 'sw00010496001xpcw3po_uf.evt.gz', 'sw00010496001xwtw2sl_cl.evt.gz', 'sw00010496001xwtw2sl_uf.evt.gz', 'sw00010496001xwtw2sl_ufre.evt.gz', 'sw00010496001xwtw2st_cl.evt.gz', 'sw00010496001xwtw2st_uf.evt.gz', 'sw00010496001xwtw2st_ufre.evt.gz']
# ['sw00010497001xpcw3po_cl.evt.gz', 'sw00010497001xpcw3po_uf.evt.gz', 'sw00010497001xwtw2sl_cl.evt.gz', 'sw00010497001xwtw2sl_uf.evt.gz', 'sw00010497001xwtw2sl_ufre.evt.gz', 'sw00010497001xwtw2st_cl.evt.gz', 'sw00010497001xwtw2st_uf.evt.gz', 'sw00010497001xwtw2st_ufre.evt.gz']
# ['sw00010570001xpcw3po_cl.evt.gz', 'sw00010570001xpcw3po_uf.evt.gz', 'sw00010570001xwtw2sl_cl.evt.gz', 'sw00010570001xwtw2sl_uf.evt.gz', 'sw00010570001xwtw2sl_ufre.evt.gz', 'sw00010570001xwtw2st_cl.evt.gz', 'sw00010570001xwtw2st_uf.evt.gz', 'sw00010570001xwtw2st_ufre.evt.gz']
# ['sw00010570002xpcw3po_cl.evt.gz', 'sw00010570002xpcw3po_uf.evt.gz', 'sw00010570002xwtw2st_cl.evt.gz', 'sw00010570002xwtw2st_uf.evt.gz', 'sw00010570002xwtw2st_ufre.evt.gz']
# ['sw00010570003xpcw3po_cl.evt.gz', 'sw00010570003xpcw3po_uf.evt.gz', 'sw00010570003xwtw2sl_cl.evt.gz', 'sw00010570003xwtw2sl_uf.evt.gz', 'sw00010570003xwtw2sl_ufre.evt.gz', 'sw00010570003xwtw2st_cl.evt.gz', 'sw00010570003xwtw2st_uf.evt.gz', 'sw00010570003xwtw2st_ufre.evt.gz']
# ['sw00010570004xpcw3po_cl.evt.gz', 'sw00010570004xpcw3po_uf.evt.gz', 'sw00010570004xwtw2st_cl.evt.gz', 'sw00010570004xwtw2st_uf.evt.gz', 'sw00010570004xwtw2st_ufre.evt.gz']
# ['sw00010570005xpcw3po_cl.evt.gz', 'sw00010570005xpcw3po_uf.evt.gz', 'sw00010570005xwtw2sl_cl.evt.gz', 'sw00010570005xwtw2sl_uf.evt.gz', 'sw00010570005xwtw2sl_ufre.evt.gz', 'sw00010570005xwtw2st_cl.evt.gz', 'sw00010570005xwtw2st_uf.evt.gz', 'sw00010570005xwtw2st_ufre.evt.gz']
# ['sw00010570006xpcw3po_cl.evt.gz', 'sw00010570006xpcw3po_uf.evt.gz', 'sw00010570006xwtw2st_cl.evt.gz', 'sw00010570006xwtw2st_uf.evt.gz', 'sw00010570006xwtw2st_ufre.evt.gz']
# ['sw00010571001xpcw3po_cl.evt.gz', 'sw00010571001xpcw3po_uf.evt.gz', 'sw00010571001xwtw2sl_cl.evt.gz', 'sw00010571001xwtw2sl_uf.evt.gz', 'sw00010571001xwtw2sl_ufre.evt.gz', 'sw00010571001xwtw2st_cl.evt.gz', 'sw00010571001xwtw2st_uf.evt.gz', 'sw00010571001xwtw2st_ufre.evt.gz']
# ['sw00010571049xpcw3po_cl.evt.gz', 'sw00010571049xpcw3po_uf.evt.gz', 'sw00010571049xwtw2po_cl.evt.gz', 'sw00010571049xwtw2po_uf.evt.gz', 'sw00010571049xwtw2po_ufre.evt.gz']
# ['sw00010571079xpcw3po_cl.evt.gz', 'sw00010571079xpcw3po_uf.evt.gz', 'sw00010571079xwtw2sl_cl.evt.gz', 'sw00010571079xwtw2sl_uf.evt.gz', 'sw00010571079xwtw2sl_ufre.evt.gz', 'sw00010571079xwtw2st_cl.evt.gz', 'sw00010571079xwtw2st_uf.evt.gz', 'sw00010571079xwtw2st_ufre.evt.gz']
# ['sw00010674002xpcw3po_cl.evt.gz', 'sw00010674002xpcw3po_uf.evt.gz', 'sw00010674002xwtw2sl_cl.evt.gz', 'sw00010674002xwtw2sl_uf.evt.gz', 'sw00010674002xwtw2sl_ufre.evt.gz', 'sw00010674002xwtw2st_cl.evt.gz', 'sw00010674002xwtw2st_uf.evt.gz', 'sw00010674002xwtw2st_ufre.evt.gz']
# ['sw00010674003xpcw3po_cl.evt.gz', 'sw00010674003xpcw3po_uf.evt.gz', 'sw00010674003xwtw2sl_cl.evt.gz', 'sw00010674003xwtw2sl_uf.evt.gz', 'sw00010674003xwtw2sl_ufre.evt.gz', 'sw00010674003xwtw2st_cl.evt.gz', 'sw00010674003xwtw2st_uf.evt.gz', 'sw00010674003xwtw2st_ufre.evt.gz']
# ['sw00010703001xpcw3po_cl.evt.gz', 'sw00010703001xpcw3po_uf.evt.gz', 'sw00010703001xwtw2sl_cl.evt.gz', 'sw00010703001xwtw2sl_uf.evt.gz', 'sw00010703001xwtw2sl_ufre.evt.gz', 'sw00010703001xwtw2st_cl.evt.gz', 'sw00010703001xwtw2st_uf.evt.gz', 'sw00010703001xwtw2st_ufre.evt.gz']
# ['sw00010703002xpcw3po_cl.evt.gz', 'sw00010703002xpcw3po_uf.evt.gz', 'sw00010703002xwtw2st_cl.evt.gz', 'sw00010703002xwtw2st_uf.evt.gz', 'sw00010703002xwtw2st_ufre.evt.gz']
# ['sw00010703003xpcw3po_cl.evt.gz', 'sw00010703003xpcw3po_uf.evt.gz', 'sw00010703003xwtw2st_cl.evt.gz', 'sw00010703003xwtw2st_uf.evt.gz', 'sw00010703003xwtw2st_ufre.evt.gz']
# ['sw00010703004xpcw3po_cl.evt.gz', 'sw00010703004xpcw3po_uf.evt.gz', 'sw00010703004xwtw2sl_cl.evt.gz', 'sw00010703004xwtw2sl_uf.evt.gz', 'sw00010703004xwtw2sl_ufre.evt.gz', 'sw00010703004xwtw2st_cl.evt.gz', 'sw00010703004xwtw2st_uf.evt.gz', 'sw00010703004xwtw2st_ufre.evt.gz']
# ['sw00010703005xpcw3po_cl.evt.gz', 'sw00010703005xpcw3po_uf.evt.gz', 'sw00010703005xwtw2sl_cl.evt.gz', 'sw00010703005xwtw2sl_uf.evt.gz', 'sw00010703005xwtw2sl_ufre.evt.gz', 'sw00010703005xwtw2st_cl.evt.gz', 'sw00010703005xwtw2st_uf.evt.gz', 'sw00010703005xwtw2st_ufre.evt.gz']
# ['sw00010703006xpcw3po_cl.evt.gz', 'sw00010703006xpcw3po_uf.evt.gz', 'sw00010703006xwtw2sl_cl.evt.gz', 'sw00010703006xwtw2sl_uf.evt.gz', 'sw00010703006xwtw2sl_ufre.evt.gz', 'sw00010703006xwtw2st_cl.evt.gz', 'sw00010703006xwtw2st_uf.evt.gz', 'sw00010703006xwtw2st_ufre.evt.gz']
# ['sw00010713002xpcw3po_cl.evt.gz', 'sw00010713002xpcw3po_uf.evt.gz', 'sw00010713002xwtw2sl_cl.evt.gz', 'sw00010713002xwtw2sl_uf.evt.gz', 'sw00010713002xwtw2sl_ufre.evt.gz', 'sw00010713002xwtw2st_cl.evt.gz', 'sw00010713002xwtw2st_uf.evt.gz', 'sw00010713002xwtw2st_ufre.evt.gz']
# ['sw00010713003xpcw3po_cl.evt.gz', 'sw00010713003xpcw3po_uf.evt.gz', 'sw00010713003xwtw2sl_cl.evt.gz', 'sw00010713003xwtw2sl_uf.evt.gz', 'sw00010713003xwtw2sl_ufre.evt.gz', 'sw00010713003xwtw2st_cl.evt.gz', 'sw00010713003xwtw2st_uf.evt.gz', 'sw00010713003xwtw2st_ufre.evt.gz']
# ['sw00010713004xpcw3po_cl.evt.gz', 'sw00010713004xpcw3po_uf.evt.gz', 'sw00010713004xwtw2sl_cl.evt.gz', 'sw00010713004xwtw2sl_uf.evt.gz', 'sw00010713004xwtw2sl_ufre.evt.gz', 'sw00010713004xwtw2st_cl.evt.gz', 'sw00010713004xwtw2st_uf.evt.gz', 'sw00010713004xwtw2st_ufre.evt.gz']
# ['sw00010713005xpcw3po_cl.evt.gz', 'sw00010713005xpcw3po_uf.evt.gz', 'sw00010713005xwtw2sl_cl.evt.gz', 'sw00010713005xwtw2sl_uf.evt.gz', 'sw00010713005xwtw2sl_ufre.evt.gz', 'sw00010713005xwtw2st_cl.evt.gz', 'sw00010713005xwtw2st_uf.evt.gz', 'sw00010713005xwtw2st_ufre.evt.gz']
# ['sw00010713006xpcw3po_cl.evt.gz', 'sw00010713006xpcw3po_uf.evt.gz', 'sw00010713006xwtw2sl_cl.evt.gz', 'sw00010713006xwtw2sl_uf.evt.gz', 'sw00010713006xwtw2sl_ufre.evt.gz', 'sw00010713006xwtw2st_cl.evt.gz', 'sw00010713006xwtw2st_uf.evt.gz', 'sw00010713006xwtw2st_ufre.evt.gz']
# ['sw00010734001xpcw3po_cl.evt.gz', 'sw00010734001xpcw3po_uf.evt.gz', 'sw00010734001xwtw2po_uf.evt.gz', 'sw00010734001xwtw2sl_cl.evt.gz', 'sw00010734001xwtw2sl_uf.evt.gz', 'sw00010734001xwtw2sl_ufre.evt.gz', 'sw00010734001xwtw2st_cl.evt.gz', 'sw00010734001xwtw2st_uf.evt.gz', 'sw00010734001xwtw2st_ufre.evt.gz']
# ['sw00010734004xpcw3po_cl.evt.gz', 'sw00010734004xpcw3po_uf.evt.gz', 'sw00010734004xwtw2po_cl.evt.gz', 'sw00010734004xwtw2po_uf.evt.gz', 'sw00010734004xwtw2po_ufre.evt.gz', 'sw00010734004xwtw2sl_cl.evt.gz', 'sw00010734004xwtw2sl_uf.evt.gz', 'sw00010734004xwtw2sl_ufre.evt.gz', 'sw00010734004xwtw2st_cl.evt.gz', 'sw00010734004xwtw2st_uf.evt.gz', 'sw00010734004xwtw2st_ufre.evt.gz']
# ['sw00010734005xpcw3po_cl.evt.gz', 'sw00010734005xpcw3po_uf.evt.gz', 'sw00010734005xwtw2po_cl.evt.gz', 'sw00010734005xwtw2po_uf.evt.gz', 'sw00010734005xwtw2po_ufre.evt.gz', 'sw00010734005xwtw2sl_cl.evt.gz', 'sw00010734005xwtw2sl_uf.evt.gz', 'sw00010734005xwtw2sl_ufre.evt.gz', 'sw00010734005xwtw2st_cl.evt.gz', 'sw00010734005xwtw2st_uf.evt.gz', 'sw00010734005xwtw2st_ufre.evt.gz']
# ['sw00010734006xpcw3po_cl.evt.gz', 'sw00010734006xpcw3po_uf.evt.gz', 'sw00010734006xwtw2po_cl.evt.gz', 'sw00010734006xwtw2po_uf.evt.gz', 'sw00010734006xwtw2po_ufre.evt.gz', 'sw00010734006xwtw2sl_cl.evt.gz', 'sw00010734006xwtw2sl_uf.evt.gz', 'sw00010734006xwtw2sl_ufre.evt.gz', 'sw00010734006xwtw2st_cl.evt.gz', 'sw00010734006xwtw2st_uf.evt.gz', 'sw00010734006xwtw2st_ufre.evt.gz']
# ['sw00010734007xpcw3po_cl.evt.gz', 'sw00010734007xpcw3po_uf.evt.gz', 'sw00010734007xwtw2po_cl.evt.gz', 'sw00010734007xwtw2po_uf.evt.gz', 'sw00010734007xwtw2po_ufre.evt.gz', 'sw00010734007xwtw2sl_cl.evt.gz', 'sw00010734007xwtw2sl_uf.evt.gz', 'sw00010734007xwtw2sl_ufre.evt.gz', 'sw00010734007xwtw2st_cl.evt.gz', 'sw00010734007xwtw2st_uf.evt.gz', 'sw00010734007xwtw2st_ufre.evt.gz']
# ['sw00010734008xpcw3po_cl.evt.gz', 'sw00010734008xpcw3po_uf.evt.gz', 'sw00010734008xwtw2po_uf.evt.gz', 'sw00010734008xwtw2sl_cl.evt.gz', 'sw00010734008xwtw2sl_uf.evt.gz', 'sw00010734008xwtw2sl_ufre.evt.gz', 'sw00010734008xwtw2st_cl.evt.gz', 'sw00010734008xwtw2st_uf.evt.gz', 'sw00010734008xwtw2st_ufre.evt.gz']
# ['sw00010734009xpcw3po_cl.evt.gz', 'sw00010734009xpcw3po_uf.evt.gz', 'sw00010734009xwtw2po_cl.evt.gz', 'sw00010734009xwtw2po_uf.evt.gz', 'sw00010734009xwtw2po_ufre.evt.gz', 'sw00010734009xwtw2sl_cl.evt.gz', 'sw00010734009xwtw2sl_uf.evt.gz', 'sw00010734009xwtw2sl_ufre.evt.gz', 'sw00010734009xwtw2st_cl.evt.gz', 'sw00010734009xwtw2st_uf.evt.gz', 'sw00010734009xwtw2st_ufre.evt.gz']
# ['sw00010734010xpcw3po_cl.evt.gz', 'sw00010734010xpcw3po_uf.evt.gz', 'sw00010734010xwtw2sl_cl.evt.gz', 'sw00010734010xwtw2sl_uf.evt.gz', 'sw00010734010xwtw2sl_ufre.evt.gz', 'sw00010734010xwtw2st_cl.evt.gz', 'sw00010734010xwtw2st_uf.evt.gz', 'sw00010734010xwtw2st_ufre.evt.gz']
# ['sw00010734011xpcw3po_cl.evt.gz', 'sw00010734011xpcw3po_uf.evt.gz', 'sw00010734011xwtw2sl_cl.evt.gz', 'sw00010734011xwtw2sl_uf.evt.gz', 'sw00010734011xwtw2sl_ufre.evt.gz', 'sw00010734011xwtw2st_cl.evt.gz', 'sw00010734011xwtw2st_uf.evt.gz', 'sw00010734011xwtw2st_ufre.evt.gz']
# ['sw00010734012xpcw3po_cl.evt.gz', 'sw00010734012xpcw3po_uf.evt.gz', 'sw00010734012xwtw2sl_cl.evt.gz', 'sw00010734012xwtw2sl_uf.evt.gz', 'sw00010734012xwtw2sl_ufre.evt.gz', 'sw00010734012xwtw2st_cl.evt.gz', 'sw00010734012xwtw2st_uf.evt.gz', 'sw00010734012xwtw2st_ufre.evt.gz']
# ['sw00010734013xpcw3po_cl.evt.gz', 'sw00010734013xpcw3po_uf.evt.gz', 'sw00010734013xwtw2st_cl.evt.gz', 'sw00010734013xwtw2st_uf.evt.gz', 'sw00010734013xwtw2st_ufre.evt.gz']
# ['sw00010734014xpcw3po_cl.evt.gz', 'sw00010734014xpcw3po_uf.evt.gz', 'sw00010734014xwtw2sl_cl.evt.gz', 'sw00010734014xwtw2sl_uf.evt.gz', 'sw00010734014xwtw2sl_ufre.evt.gz', 'sw00010734014xwtw2st_cl.evt.gz', 'sw00010734014xwtw2st_uf.evt.gz', 'sw00010734014xwtw2st_ufre.evt.gz']
# ['sw00010734015xpcw3po_cl.evt.gz', 'sw00010734015xpcw3po_uf.evt.gz', 'sw00010734015xwtw2sl_cl.evt.gz', 'sw00010734015xwtw2sl_uf.evt.gz', 'sw00010734015xwtw2sl_ufre.evt.gz', 'sw00010734015xwtw2st_cl.evt.gz', 'sw00010734015xwtw2st_uf.evt.gz', 'sw00010734015xwtw2st_ufre.evt.gz']
# ['sw00010734016xpcw3po_cl.evt.gz', 'sw00010734016xpcw3po_uf.evt.gz', 'sw00010734016xwtw2sl_cl.evt.gz', 'sw00010734016xwtw2sl_uf.evt.gz', 'sw00010734016xwtw2sl_ufre.evt.gz', 'sw00010734016xwtw2st_cl.evt.gz', 'sw00010734016xwtw2st_uf.evt.gz', 'sw00010734016xwtw2st_ufre.evt.gz']
# ['sw00010734017xpcw3po_cl.evt.gz', 'sw00010734017xpcw3po_uf.evt.gz', 'sw00010734017xwtw2sl_cl.evt.gz', 'sw00010734017xwtw2sl_uf.evt.gz', 'sw00010734017xwtw2sl_ufre.evt.gz', 'sw00010734017xwtw2st_cl.evt.gz', 'sw00010734017xwtw2st_uf.evt.gz', 'sw00010734017xwtw2st_ufre.evt.gz']
# ['sw00010734018xpcw3po_cl.evt.gz', 'sw00010734018xpcw3po_uf.evt.gz', 'sw00010734018xwtw2sl_cl.evt.gz', 'sw00010734018xwtw2sl_uf.evt.gz', 'sw00010734018xwtw2sl_ufre.evt.gz', 'sw00010734018xwtw2st_cl.evt.gz', 'sw00010734018xwtw2st_uf.evt.gz', 'sw00010734018xwtw2st_ufre.evt.gz']
# ['sw00010734019xpcw3po_cl.evt.gz', 'sw00010734019xpcw3po_uf.evt.gz', 'sw00010734019xwtw2sl_cl.evt.gz', 'sw00010734019xwtw2sl_uf.evt.gz', 'sw00010734019xwtw2sl_ufre.evt.gz', 'sw00010734019xwtw2st_cl.evt.gz', 'sw00010734019xwtw2st_uf.evt.gz', 'sw00010734019xwtw2st_ufre.evt.gz']
# ['sw00010734021xpcw3po_cl.evt.gz', 'sw00010734021xpcw3po_uf.evt.gz', 'sw00010734021xwtw2sl_cl.evt.gz', 'sw00010734021xwtw2sl_uf.evt.gz', 'sw00010734021xwtw2sl_ufre.evt.gz', 'sw00010734021xwtw2st_cl.evt.gz', 'sw00010734021xwtw2st_uf.evt.gz', 'sw00010734021xwtw2st_ufre.evt.gz']
# ['sw00010734022xpcw3po_cl.evt.gz', 'sw00010734022xpcw3po_uf.evt.gz', 'sw00010734022xwtw2sl_cl.evt.gz', 'sw00010734022xwtw2sl_uf.evt.gz', 'sw00010734022xwtw2sl_ufre.evt.gz', 'sw00010734022xwtw2st_cl.evt.gz', 'sw00010734022xwtw2st_uf.evt.gz', 'sw00010734022xwtw2st_ufre.evt.gz']
# ['sw00010734023xpcw3po_cl.evt.gz', 'sw00010734023xpcw3po_uf.evt.gz', 'sw00010734023xwtw2sl_cl.evt.gz', 'sw00010734023xwtw2sl_uf.evt.gz', 'sw00010734023xwtw2sl_ufre.evt.gz', 'sw00010734023xwtw2st_cl.evt.gz', 'sw00010734023xwtw2st_uf.evt.gz', 'sw00010734023xwtw2st_ufre.evt.gz']
# ['sw00010734024xpcw3po_cl.evt.gz', 'sw00010734024xpcw3po_uf.evt.gz', 'sw00010734024xwtw2sl_cl.evt.gz', 'sw00010734024xwtw2sl_uf.evt.gz', 'sw00010734024xwtw2sl_ufre.evt.gz', 'sw00010734024xwtw2st_cl.evt.gz', 'sw00010734024xwtw2st_uf.evt.gz', 'sw00010734024xwtw2st_ufre.evt.gz']
# ['sw00010734025xpcw3po_cl.evt.gz', 'sw00010734025xpcw3po_uf.evt.gz', 'sw00010734025xwtw2sl_cl.evt.gz', 'sw00010734025xwtw2sl_uf.evt.gz', 'sw00010734025xwtw2sl_ufre.evt.gz', 'sw00010734025xwtw2st_cl.evt.gz', 'sw00010734025xwtw2st_uf.evt.gz', 'sw00010734025xwtw2st_ufre.evt.gz']
# ['sw00010734026xpcw3po_cl.evt.gz', 'sw00010734026xpcw3po_uf.evt.gz', 'sw00010734026xwtw2sl_cl.evt.gz', 'sw00010734026xwtw2sl_uf.evt.gz', 'sw00010734026xwtw2sl_ufre.evt.gz', 'sw00010734026xwtw2st_cl.evt.gz', 'sw00010734026xwtw2st_uf.evt.gz', 'sw00010734026xwtw2st_ufre.evt.gz']
# ['sw00010734027xpcw3po_cl.evt.gz', 'sw00010734027xpcw3po_uf.evt.gz', 'sw00010734027xwtw2sl_cl.evt.gz', 'sw00010734027xwtw2sl_uf.evt.gz', 'sw00010734027xwtw2sl_ufre.evt.gz', 'sw00010734027xwtw2st_cl.evt.gz', 'sw00010734027xwtw2st_uf.evt.gz', 'sw00010734027xwtw2st_ufre.evt.gz']
# ['sw00010734028xpcw3po_cl.evt.gz', 'sw00010734028xpcw3po_uf.evt.gz', 'sw00010734028xwtw2sl_cl.evt.gz', 'sw00010734028xwtw2sl_uf.evt.gz', 'sw00010734028xwtw2sl_ufre.evt.gz', 'sw00010734028xwtw2st_cl.evt.gz', 'sw00010734028xwtw2st_uf.evt.gz', 'sw00010734028xwtw2st_ufre.evt.gz']
# ['sw00010734029xpcw3po_cl.evt.gz', 'sw00010734029xpcw3po_uf.evt.gz', 'sw00010734029xwtw2sl_cl.evt.gz', 'sw00010734029xwtw2sl_uf.evt.gz', 'sw00010734029xwtw2sl_ufre.evt.gz', 'sw00010734029xwtw2st_cl.evt.gz', 'sw00010734029xwtw2st_uf.evt.gz', 'sw00010734029xwtw2st_ufre.evt.gz']
# ['sw00010734030xpcw3po_cl.evt.gz', 'sw00010734030xpcw3po_uf.evt.gz', 'sw00010734030xwtw2sl_cl.evt.gz', 'sw00010734030xwtw2sl_uf.evt.gz', 'sw00010734030xwtw2sl_ufre.evt.gz', 'sw00010734030xwtw2st_cl.evt.gz', 'sw00010734030xwtw2st_uf.evt.gz', 'sw00010734030xwtw2st_ufre.evt.gz']
# ...
# ['sw03110787002xpcw3po_cl.evt.gz', 'sw03110787002xpcw3po_uf.evt.gz', 'sw03110787002xwtw2sl_cl.evt.gz', 'sw03110787002xwtw2sl_uf.evt.gz', 'sw03110787002xwtw2sl_ufre.evt.gz', 'sw03110787002xwtw2st_cl.evt.gz', 'sw03110787002xwtw2st_uf.evt.gz', 'sw03110787002xwtw2st_ufre.evt.gz']
# ['sw03110787003xpcw3po_cl.evt.gz', 'sw03110787003xpcw3po_uf.evt.gz', 'sw03110787003xwtw2sl_cl.evt.gz', 'sw03110787003xwtw2sl_uf.evt.gz', 'sw03110787003xwtw2sl_ufre.evt.gz', 'sw03110787003xwtw2st_cl.evt.gz', 'sw03110787003xwtw2st_uf.evt.gz', 'sw03110787003xwtw2st_ufre.evt.gz']
# ['sw03110788001xpcw3po_cl.evt.gz', 'sw03110788001xpcw3po_uf.evt.gz', 'sw03110788001xwtw2sl_cl.evt.gz', 'sw03110788001xwtw2sl_uf.evt.gz', 'sw03110788001xwtw2sl_ufre.evt.gz', 'sw03110788001xwtw2st_cl.evt.gz', 'sw03110788001xwtw2st_uf.evt.gz', 'sw03110788001xwtw2st_ufre.evt.gz']
# ['sw03110788002xpcw3po_cl.evt.gz', 'sw03110788002xpcw3po_uf.evt.gz', 'sw03110788002xwtw2sl_cl.evt.gz', 'sw03110788002xwtw2sl_uf.evt.gz', 'sw03110788002xwtw2sl_ufre.evt.gz', 'sw03110788002xwtw2st_cl.evt.gz', 'sw03110788002xwtw2st_uf.evt.gz', 'sw03110788002xwtw2st_ufre.evt.gz']
# ['sw03110789001xpcw3po_cl.evt.gz', 'sw03110789001xpcw3po_uf.evt.gz', 'sw03110789001xwtw2sl_cl.evt.gz', 'sw03110789001xwtw2sl_uf.evt.gz', 'sw03110789001xwtw2sl_ufre.evt.gz', 'sw03110789001xwtw2st_cl.evt.gz', 'sw03110789001xwtw2st_uf.evt.gz', 'sw03110789001xwtw2st_ufre.evt.gz']
# ['sw03110789002xpcw3po_cl.evt.gz', 'sw03110789002xpcw3po_uf.evt.gz', 'sw03110789002xwtw2sl_cl.evt.gz', 'sw03110789002xwtw2sl_uf.evt.gz', 'sw03110789002xwtw2sl_ufre.evt.gz', 'sw03110789002xwtw2st_cl.evt.gz', 'sw03110789002xwtw2st_uf.evt.gz', 'sw03110789002xwtw2st_ufre.evt.gz']
# ['sw03110789003xpcw3po_cl.evt.gz', 'sw03110789003xpcw3po_uf.evt.gz', 'sw03110789003xwtw2st_cl.evt.gz', 'sw03110789003xwtw2st_uf.evt.gz', 'sw03110789003xwtw2st_ufre.evt.gz']
# ['sw03110790001xpcw3po_cl.evt.gz', 'sw03110790001xpcw3po_uf.evt.gz', 'sw03110790001xwtw2sl_cl.evt.gz', 'sw03110790001xwtw2sl_uf.evt.gz', 'sw03110790001xwtw2sl_ufre.evt.gz', 'sw03110790001xwtw2st_cl.evt.gz', 'sw03110790001xwtw2st_uf.evt.gz', 'sw03110790001xwtw2st_ufre.evt.gz']
# ['sw03110791001xpcw3po_cl.evt.gz', 'sw03110791001xpcw3po_uf.evt.gz', 'sw03110791001xwtw2sl_cl.evt.gz', 'sw03110791001xwtw2sl_uf.evt.gz', 'sw03110791001xwtw2sl_ufre.evt.gz', 'sw03110791001xwtw2st_cl.evt.gz', 'sw03110791001xwtw2st_uf.evt.gz', 'sw03110791001xwtw2st_ufre.evt.gz']
# ['sw03110792001xpcw3po_cl.evt.gz', 'sw03110792001xpcw3po_uf.evt.gz', 'sw03110792001xwtw2sl_cl.evt.gz', 'sw03110792001xwtw2sl_uf.evt.gz', 'sw03110792001xwtw2sl_ufre.evt.gz', 'sw03110792001xwtw2st_cl.evt.gz', 'sw03110792001xwtw2st_uf.evt.gz', 'sw03110792001xwtw2st_ufre.evt.gz']
# ['sw03110792002xpcw3po_cl.evt.gz', 'sw03110792002xpcw3po_uf.evt.gz', 'sw03110792002xwtw2sl_cl.evt.gz', 'sw03110792002xwtw2sl_uf.evt.gz', 'sw03110792002xwtw2sl_ufre.evt.gz', 'sw03110792002xwtw2st_cl.evt.gz', 'sw03110792002xwtw2st_uf.evt.gz', 'sw03110792002xwtw2st_ufre.evt.gz']
# ['sw03110792003xpcw3po_cl.evt.gz', 'sw03110792003xpcw3po_uf.evt.gz', 'sw03110792003xwtw2sl_cl.evt.gz', 'sw03110792003xwtw2sl_uf.evt.gz', 'sw03110792003xwtw2sl_ufre.evt.gz', 'sw03110792003xwtw2st_cl.evt.gz', 'sw03110792003xwtw2st_uf.evt.gz', 'sw03110792003xwtw2st_ufre.evt.gz']
# ['sw03110793001xpcw3po_cl.evt.gz', 'sw03110793001xpcw3po_uf.evt.gz', 'sw03110793001xwtw2sl_cl.evt.gz', 'sw03110793001xwtw2sl_uf.evt.gz', 'sw03110793001xwtw2sl_ufre.evt.gz', 'sw03110793001xwtw2st_cl.evt.gz', 'sw03110793001xwtw2st_uf.evt.gz', 'sw03110793001xwtw2st_ufre.evt.gz']
# ['sw03110793002xpcw3po_cl.evt.gz', 'sw03110793002xpcw3po_uf.evt.gz', 'sw03110793002xwtw2st_cl.evt.gz', 'sw03110793002xwtw2st_uf.evt.gz', 'sw03110793002xwtw2st_ufre.evt.gz']
# ['sw03110794001xpcw3po_cl.evt.gz', 'sw03110794001xpcw3po_uf.evt.gz', 'sw03110794001xwtw2sl_cl.evt.gz', 'sw03110794001xwtw2sl_uf.evt.gz', 'sw03110794001xwtw2sl_ufre.evt.gz', 'sw03110794001xwtw2st_cl.evt.gz', 'sw03110794001xwtw2st_uf.evt.gz', 'sw03110794001xwtw2st_ufre.evt.gz']
# ['sw03110794002xpcw3po_cl.evt.gz', 'sw03110794002xpcw3po_uf.evt.gz', 'sw03110794002xwtw2sl_cl.evt.gz', 'sw03110794002xwtw2sl_uf.evt.gz', 'sw03110794002xwtw2sl_ufre.evt.gz', 'sw03110794002xwtw2st_cl.evt.gz', 'sw03110794002xwtw2st_uf.evt.gz', 'sw03110794002xwtw2st_ufre.evt.gz']
# ['sw03110795001xpcw3po_cl.evt.gz', 'sw03110795001xpcw3po_uf.evt.gz', 'sw03110795001xwtw2sl_cl.evt.gz', 'sw03110795001xwtw2sl_uf.evt.gz', 'sw03110795001xwtw2sl_ufre.evt.gz', 'sw03110795001xwtw2st_cl.evt.gz', 'sw03110795001xwtw2st_uf.evt.gz', 'sw03110795001xwtw2st_ufre.evt.gz']
# ['sw03110795002xpcw3po_cl.evt.gz', 'sw03110795002xpcw3po_uf.evt.gz', 'sw03110795002xwtw2sl_cl.evt.gz', 'sw03110795002xwtw2sl_uf.evt.gz', 'sw03110795002xwtw2sl_ufre.evt.gz', 'sw03110795002xwtw2st_cl.evt.gz', 'sw03110795002xwtw2st_uf.evt.gz', 'sw03110795002xwtw2st_ufre.evt.gz']
# ['sw03110796001xpcw3po_cl.evt.gz', 'sw03110796001xpcw3po_uf.evt.gz', 'sw03110796001xwtw2sl_cl.evt.gz', 'sw03110796001xwtw2sl_uf.evt.gz', 'sw03110796001xwtw2sl_ufre.evt.gz', 'sw03110796001xwtw2st_cl.evt.gz', 'sw03110796001xwtw2st_uf.evt.gz', 'sw03110796001xwtw2st_ufre.evt.gz']
# ['sw03110796002xpcw3po_cl.evt.gz', 'sw03110796002xpcw3po_uf.evt.gz', 'sw03110796002xwtw2sl_cl.evt.gz', 'sw03110796002xwtw2sl_uf.evt.gz', 'sw03110796002xwtw2sl_ufre.evt.gz', 'sw03110796002xwtw2st_cl.evt.gz', 'sw03110796002xwtw2st_uf.evt.gz', 'sw03110796002xwtw2st_ufre.evt.gz']
# ['sw03110796003xpcw3po_cl.evt.gz', 'sw03110796003xpcw3po_uf.evt.gz', 'sw03110796003xwtw2sl_cl.evt.gz', 'sw03110796003xwtw2sl_uf.evt.gz', 'sw03110796003xwtw2sl_ufre.evt.gz', 'sw03110796003xwtw2st_cl.evt.gz', 'sw03110796003xwtw2st_uf.evt.gz', 'sw03110796003xwtw2st_ufre.evt.gz']
# ['sw03110797001xpcw3po_cl.evt.gz', 'sw03110797001xpcw3po_uf.evt.gz', 'sw03110797001xwtw2sl_cl.evt.gz', 'sw03110797001xwtw2sl_uf.evt.gz', 'sw03110797001xwtw2sl_ufre.evt.gz', 'sw03110797001xwtw2st_cl.evt.gz', 'sw03110797001xwtw2st_uf.evt.gz', 'sw03110797001xwtw2st_ufre.evt.gz']
# ['sw03110797002xpcw3po_cl.evt.gz', 'sw03110797002xpcw3po_uf.evt.gz', 'sw03110797002xwtw2sl_cl.evt.gz', 'sw03110797002xwtw2sl_uf.evt.gz', 'sw03110797002xwtw2sl_ufre.evt.gz', 'sw03110797002xwtw2st_cl.evt.gz', 'sw03110797002xwtw2st_uf.evt.gz', 'sw03110797002xwtw2st_ufre.evt.gz']
# ['sw03110801001xpcw3po_cl.evt.gz', 'sw03110801001xpcw3po_uf.evt.gz', 'sw03110801001xwtw2sl_cl.evt.gz', 'sw03110801001xwtw2sl_uf.evt.gz', 'sw03110801001xwtw2sl_ufre.evt.gz', 'sw03110801001xwtw2st_cl.evt.gz', 'sw03110801001xwtw2st_uf.evt.gz', 'sw03110801001xwtw2st_ufre.evt.gz']
# ['sw03110802001xpcw3po_cl.evt.gz', 'sw03110802001xpcw3po_uf.evt.gz', 'sw03110802001xwtw2sl_cl.evt.gz', 'sw03110802001xwtw2sl_uf.evt.gz', 'sw03110802001xwtw2sl_ufre.evt.gz', 'sw03110802001xwtw2st_cl.evt.gz', 'sw03110802001xwtw2st_uf.evt.gz', 'sw03110802001xwtw2st_ufre.evt.gz']
# ['sw03110802003xpcw3po_cl.evt.gz', 'sw03110802003xpcw3po_uf.evt.gz', 'sw03110802003xwtw2sl_cl.evt.gz', 'sw03110802003xwtw2sl_uf.evt.gz', 'sw03110802003xwtw2sl_ufre.evt.gz', 'sw03110802003xwtw2st_cl.evt.gz', 'sw03110802003xwtw2st_uf.evt.gz', 'sw03110802003xwtw2st_ufre.evt.gz']
# ['sw03110803001xpcw3po_cl.evt.gz', 'sw03110803001xpcw3po_uf.evt.gz', 'sw03110803001xwtw2sl_cl.evt.gz', 'sw03110803001xwtw2sl_uf.evt.gz', 'sw03110803001xwtw2sl_ufre.evt.gz', 'sw03110803001xwtw2st_cl.evt.gz', 'sw03110803001xwtw2st_uf.evt.gz', 'sw03110803001xwtw2st_ufre.evt.gz']
# ['sw03110804001xpcw3po_cl.evt.gz', 'sw03110804001xpcw3po_uf.evt.gz', 'sw03110804001xwtw2sl_cl.evt.gz', 'sw03110804001xwtw2sl_uf.evt.gz', 'sw03110804001xwtw2sl_ufre.evt.gz', 'sw03110804001xwtw2st_cl.evt.gz', 'sw03110804001xwtw2st_uf.evt.gz', 'sw03110804001xwtw2st_ufre.evt.gz']
# ['sw03110804002xpcw3po_cl.evt.gz', 'sw03110804002xpcw3po_uf.evt.gz', 'sw03110804002xwtw2sl_cl.evt.gz', 'sw03110804002xwtw2sl_uf.evt.gz', 'sw03110804002xwtw2sl_ufre.evt.gz', 'sw03110804002xwtw2st_cl.evt.gz', 'sw03110804002xwtw2st_uf.evt.gz', 'sw03110804002xwtw2st_ufre.evt.gz']
# ['sw03110804003xpcw3po_cl.evt.gz', 'sw03110804003xpcw3po_uf.evt.gz', 'sw03110804003xwtw2sl_cl.evt.gz', 'sw03110804003xwtw2sl_uf.evt.gz', 'sw03110804003xwtw2sl_ufre.evt.gz', 'sw03110804003xwtw2st_cl.evt.gz', 'sw03110804003xwtw2st_uf.evt.gz', 'sw03110804003xwtw2st_ufre.evt.gz']
# ['sw03110805001xpcw3po_cl.evt.gz', 'sw03110805001xpcw3po_uf.evt.gz', 'sw03110805001xwtw2sl_cl.evt.gz', 'sw03110805001xwtw2sl_uf.evt.gz', 'sw03110805001xwtw2sl_ufre.evt.gz', 'sw03110805001xwtw2st_cl.evt.gz', 'sw03110805001xwtw2st_uf.evt.gz', 'sw03110805001xwtw2st_ufre.evt.gz']
# ['sw03110806001xpcw3po_cl.evt.gz', 'sw03110806001xpcw3po_uf.evt.gz', 'sw03110806001xwtw2sl_cl.evt.gz', 'sw03110806001xwtw2sl_uf.evt.gz', 'sw03110806001xwtw2sl_ufre.evt.gz', 'sw03110806001xwtw2st_cl.evt.gz', 'sw03110806001xwtw2st_uf.evt.gz', 'sw03110806001xwtw2st_ufre.evt.gz']
# ['sw03110806002xpcw3po_cl.evt.gz', 'sw03110806002xpcw3po_uf.evt.gz', 'sw03110806002xwtw2sl_cl.evt.gz', 'sw03110806002xwtw2sl_uf.evt.gz', 'sw03110806002xwtw2sl_ufre.evt.gz', 'sw03110806002xwtw2st_cl.evt.gz', 'sw03110806002xwtw2st_uf.evt.gz', 'sw03110806002xwtw2st_ufre.evt.gz']
# ['sw03110807001xpcw3po_cl.evt.gz', 'sw03110807001xpcw3po_uf.evt.gz', 'sw03110807001xwtw2sl_cl.evt.gz', 'sw03110807001xwtw2sl_uf.evt.gz', 'sw03110807001xwtw2sl_ufre.evt.gz', 'sw03110807001xwtw2st_cl.evt.gz', 'sw03110807001xwtw2st_uf.evt.gz', 'sw03110807001xwtw2st_ufre.evt.gz']
# ['sw03110808001xpcw3po_cl.evt.gz', 'sw03110808001xpcw3po_uf.evt.gz', 'sw03110808001xwtw2sl_cl.evt.gz', 'sw03110808001xwtw2sl_uf.evt.gz', 'sw03110808001xwtw2sl_ufre.evt.gz', 'sw03110808001xwtw2st_cl.evt.gz', 'sw03110808001xwtw2st_uf.evt.gz', 'sw03110808001xwtw2st_ufre.evt.gz']
# ['sw03110809001xpcw3po_cl.evt.gz', 'sw03110809001xpcw3po_uf.evt.gz', 'sw03110809001xwtw2sl_cl.evt.gz', 'sw03110809001xwtw2sl_uf.evt.gz', 'sw03110809001xwtw2sl_ufre.evt.gz', 'sw03110809001xwtw2st_cl.evt.gz', 'sw03110809001xwtw2st_uf.evt.gz', 'sw03110809001xwtw2st_ufre.evt.gz']
# ['sw03110810001xpcw3po_cl.evt.gz', 'sw03110810001xpcw3po_uf.evt.gz', 'sw03110810001xwtw2sl_cl.evt.gz', 'sw03110810001xwtw2sl_uf.evt.gz', 'sw03110810001xwtw2sl_ufre.evt.gz', 'sw03110810001xwtw2st_cl.evt.gz', 'sw03110810001xwtw2st_uf.evt.gz', 'sw03110810001xwtw2st_ufre.evt.gz']
# ['sw03110810002xpcw3po_cl.evt.gz', 'sw03110810002xpcw3po_uf.evt.gz', 'sw03110810002xwtw2sl_cl.evt.gz', 'sw03110810002xwtw2sl_uf.evt.gz', 'sw03110810002xwtw2sl_ufre.evt.gz', 'sw03110810002xwtw2st_cl.evt.gz', 'sw03110810002xwtw2st_uf.evt.gz', 'sw03110810002xwtw2st_ufre.evt.gz']
# ['sw03110810003xpcw3po_cl.evt.gz', 'sw03110810003xpcw3po_uf.evt.gz', 'sw03110810003xwtw2sl_cl.evt.gz', 'sw03110810003xwtw2sl_uf.evt.gz', 'sw03110810003xwtw2sl_ufre.evt.gz', 'sw03110810003xwtw2st_cl.evt.gz', 'sw03110810003xwtw2st_uf.evt.gz', 'sw03110810003xwtw2st_ufre.evt.gz']
# ['sw03110811001xpcw3po_cl.evt.gz', 'sw03110811001xpcw3po_uf.evt.gz', 'sw03110811001xwtw2sl_cl.evt.gz', 'sw03110811001xwtw2sl_uf.evt.gz', 'sw03110811001xwtw2sl_ufre.evt.gz', 'sw03110811001xwtw2st_cl.evt.gz', 'sw03110811001xwtw2st_uf.evt.gz', 'sw03110811001xwtw2st_ufre.evt.gz']
# ['sw03110811002xpcw3po_cl.evt.gz', 'sw03110811002xpcw3po_uf.evt.gz', 'sw03110811002xwtw2sl_cl.evt.gz', 'sw03110811002xwtw2sl_uf.evt.gz', 'sw03110811002xwtw2sl_ufre.evt.gz', 'sw03110811002xwtw2st_cl.evt.gz', 'sw03110811002xwtw2st_uf.evt.gz', 'sw03110811002xwtw2st_ufre.evt.gz']
# ['sw03110812001xpcw3po_cl.evt.gz', 'sw03110812001xpcw3po_uf.evt.gz', 'sw03110812001xwtw2sl_cl.evt.gz', 'sw03110812001xwtw2sl_uf.evt.gz', 'sw03110812001xwtw2sl_ufre.evt.gz', 'sw03110812001xwtw2st_cl.evt.gz', 'sw03110812001xwtw2st_uf.evt.gz', 'sw03110812001xwtw2st_ufre.evt.gz']
# ['sw03110813001xpcw3po_cl.evt.gz', 'sw03110813001xpcw3po_uf.evt.gz', 'sw03110813001xwtw2sl_cl.evt.gz', 'sw03110813001xwtw2sl_uf.evt.gz', 'sw03110813001xwtw2sl_ufre.evt.gz', 'sw03110813001xwtw2st_cl.evt.gz', 'sw03110813001xwtw2st_uf.evt.gz', 'sw03110813001xwtw2st_ufre.evt.gz']
# ['sw03110813002xpcw3po_cl.evt.gz', 'sw03110813002xpcw3po_uf.evt.gz', 'sw03110813002xwtw2sl_cl.evt.gz', 'sw03110813002xwtw2sl_uf.evt.gz', 'sw03110813002xwtw2sl_ufre.evt.gz', 'sw03110813002xwtw2st_cl.evt.gz', 'sw03110813002xwtw2st_uf.evt.gz', 'sw03110813002xwtw2st_ufre.evt.gz']
# ['sw03110814001xpcw3po_cl.evt.gz', 'sw03110814001xpcw3po_uf.evt.gz', 'sw03110814001xwtw2sl_cl.evt.gz', 'sw03110814001xwtw2sl_uf.evt.gz', 'sw03110814001xwtw2sl_ufre.evt.gz', 'sw03110814001xwtw2st_cl.evt.gz', 'sw03110814001xwtw2st_uf.evt.gz', 'sw03110814001xwtw2st_ufre.evt.gz']
# ['sw03110814002xpcw3po_cl.evt.gz', 'sw03110814002xpcw3po_uf.evt.gz', 'sw03110814002xwtw2sl_cl.evt.gz', 'sw03110814002xwtw2sl_uf.evt.gz', 'sw03110814002xwtw2sl_ufre.evt.gz', 'sw03110814002xwtw2st_cl.evt.gz', 'sw03110814002xwtw2st_uf.evt.gz', 'sw03110814002xwtw2st_ufre.evt.gz']
# ['sw03110815001xpcw3po_cl.evt.gz', 'sw03110815001xpcw3po_uf.evt.gz', 'sw03110815001xwtw2sl_cl.evt.gz', 'sw03110815001xwtw2sl_uf.evt.gz', 'sw03110815001xwtw2sl_ufre.evt.gz', 'sw03110815001xwtw2st_cl.evt.gz', 'sw03110815001xwtw2st_uf.evt.gz', 'sw03110815001xwtw2st_ufre.evt.gz']
# ['sw03110815002xpcw3po_cl.evt.gz', 'sw03110815002xpcw3po_uf.evt.gz', 'sw03110815002xwtw2sl_cl.evt.gz', 'sw03110815002xwtw2sl_uf.evt.gz', 'sw03110815002xwtw2sl_ufre.evt.gz', 'sw03110815002xwtw2st_cl.evt.gz', 'sw03110815002xwtw2st_uf.evt.gz', 'sw03110815002xwtw2st_ufre.evt.gz']
# ['sw03110815003xpcw3po_cl.evt.gz', 'sw03110815003xpcw3po_uf.evt.gz', 'sw03110815003xwtw2st_cl.evt.gz', 'sw03110815003xwtw2st_uf.evt.gz', 'sw03110815003xwtw2st_ufre.evt.gz']
# ['sw03110816001xpcw3po_cl.evt.gz', 'sw03110816001xpcw3po_uf.evt.gz', 'sw03110816001xwtw2sl_cl.evt.gz', 'sw03110816001xwtw2sl_uf.evt.gz', 'sw03110816001xwtw2sl_ufre.evt.gz', 'sw03110816001xwtw2st_cl.evt.gz', 'sw03110816001xwtw2st_uf.evt.gz', 'sw03110816001xwtw2st_ufre.evt.gz']
# ['sw03110816002xpcw3po_cl.evt.gz', 'sw03110816002xpcw3po_uf.evt.gz', 'sw03110816002xwtw2sl_cl.evt.gz', 'sw03110816002xwtw2sl_uf.evt.gz', 'sw03110816002xwtw2sl_ufre.evt.gz', 'sw03110816002xwtw2st_cl.evt.gz', 'sw03110816002xwtw2st_uf.evt.gz', 'sw03110816002xwtw2st_ufre.evt.gz']
# ['sw03110817001xpcw3po_cl.evt.gz', 'sw03110817001xpcw3po_uf.evt.gz', 'sw03110817001xwtw2sl_cl.evt.gz', 'sw03110817001xwtw2sl_uf.evt.gz', 'sw03110817001xwtw2sl_ufre.evt.gz', 'sw03110817001xwtw2st_cl.evt.gz', 'sw03110817001xwtw2st_uf.evt.gz', 'sw03110817001xwtw2st_ufre.evt.gz']
# ['sw03110817002xpcw3po_cl.evt.gz', 'sw03110817002xpcw3po_uf.evt.gz', 'sw03110817002xwtw2sl_cl.evt.gz', 'sw03110817002xwtw2sl_uf.evt.gz', 'sw03110817002xwtw2sl_ufre.evt.gz', 'sw03110817002xwtw2st_cl.evt.gz', 'sw03110817002xwtw2st_uf.evt.gz', 'sw03110817002xwtw2st_ufre.evt.gz']
# ['sw03110817003xpcw3po_cl.evt.gz', 'sw03110817003xpcw3po_uf.evt.gz', 'sw03110817003xwtw2sl_cl.evt.gz', 'sw03110817003xwtw2sl_uf.evt.gz', 'sw03110817003xwtw2sl_ufre.evt.gz', 'sw03110817003xwtw2st_cl.evt.gz', 'sw03110817003xwtw2st_uf.evt.gz', 'sw03110817003xwtw2st_ufre.evt.gz']
# ['sw03110818001xpcw3po_cl.evt.gz', 'sw03110818001xpcw3po_uf.evt.gz', 'sw03110818001xwtw2sl_cl.evt.gz', 'sw03110818001xwtw2sl_uf.evt.gz', 'sw03110818001xwtw2sl_ufre.evt.gz', 'sw03110818001xwtw2st_cl.evt.gz', 'sw03110818001xwtw2st_uf.evt.gz', 'sw03110818001xwtw2st_ufre.evt.gz']
# ['sw03110818002xpcw3po_cl.evt.gz', 'sw03110818002xpcw3po_uf.evt.gz', 'sw03110818002xwtw2sl_cl.evt.gz', 'sw03110818002xwtw2sl_uf.evt.gz', 'sw03110818002xwtw2sl_ufre.evt.gz', 'sw03110818002xwtw2st_cl.evt.gz', 'sw03110818002xwtw2st_uf.evt.gz', 'sw03110818002xwtw2st_ufre.evt.gz']
# ['sw03110818003xpcw3po_cl.evt.gz', 'sw03110818003xpcw3po_uf.evt.gz', 'sw03110818003xwtw2sl_cl.evt.gz', 'sw03110818003xwtw2sl_uf.evt.gz', 'sw03110818003xwtw2sl_ufre.evt.gz', 'sw03110818003xwtw2st_cl.evt.gz', 'sw03110818003xwtw2st_uf.evt.gz', 'sw03110818003xwtw2st_ufre.evt.gz']
# ['sw07030730001xpcw3po_cl.evt.gz', 'sw07030730001xpcw3po_uf.evt.gz', 'sw07030730001xwtw2st_cl.evt.gz', 'sw07030730001xwtw2st_uf.evt.gz', 'sw07030730001xwtw2st_ufre.evt.gz']
# ['sw07030730002xpcw3po_cl.evt.gz', 'sw07030730002xpcw3po_uf.evt.gz', 'sw07030730002xwtw2sl_cl.evt.gz', 'sw07030730002xwtw2sl_uf.evt.gz', 'sw07030730002xwtw2sl_ufre.evt.gz', 'sw07030730002xwtw2st_cl.evt.gz', 'sw07030730002xwtw2st_uf.evt.gz', 'sw07030730002xwtw2st_ufre.evt.gz']
